# %% [markdown]
# ## IMPORTS

# %%
import numpy as np
import tifffile as tiff
from skimage.morphology import skeletonize  # Import for skeletonization
from skan import Skeleton, summarize
from joblib import Parallel, delayed
import sys
import cc3d

sys.path.append('C:/Users/nerea/Documents/MasterDTU/SpacialCourse_Fall24/specialCourse_fall24')
from cleaning_functions.cleaning_functions import neighbors, is_junction_point, remove_branches, print_branches
from cleaning_functions.connecting_functions import connect_blobs_3d

# %% [markdown]
# ## BOTTOM - GT

# %%
binary_volume = tiff.imread("C:/Users/nerea/Documents/MasterDTU/SpacialCourse_Fall24/specialCourse_fall24/outputs/FINAL/skeleleton_clean_x20_th5_BOTTOM.tif")

skel = Skeleton(binary_volume)
branch_data = summarize(skel)

labels_out = cc3d.connected_components(binary_volume)
labels_out, N = cc3d.connected_components(binary_volume, return_N=True)
print(f'Number of LAbels: {N}')

# Initialize a dictionary to map each branch ID to its corresponding blob(s)
branch_blob_mapping = {}
pixel_blob_mapping = np.zeros_like(labels_out, dtype=int)

# Step 2: For each branch, get the coordinates and map them to the corresponding blob label(s)
for branch_id in branch_data.index:
    # Get the coordinates of the current branch in the skeleton structure
    coordinates = skel.path_coordinates(branch_id)
    
    # Fetch the labels at those coordinates from the labels_out array
    branch_labels = labels_out[coordinates[:, 0], coordinates[:, 1], coordinates[:, 2]]
    
    # Find the unique label(s) associated with this branch
    unique_blob_labels = np.unique(branch_labels)
    
    # Store the unique label(s) in the branch_blob_mapping
    if len(unique_blob_labels) > 1:
        branch_blob_mapping[branch_id] = unique_blob_labels
    else:
        branch_blob_mapping[branch_id] = unique_blob_labels[0]
    
    # Step 3: Map each pixel in this branch to its corresponding blob label(s)
    for i, coord in enumerate(coordinates):
        pixel_blob_mapping[tuple(coord)] = branch_labels[i]


binary_volume_copy = np.copy(binary_volume)
while True:
    # Paso 4: Repetir los pasos 2 y 3 hasta que todos los blobs estén conectados
    binary_volume_copy = connect_blobs_3d(labels_out, pixel_blob_mapping, binary_volume_copy)
    
    # Free up memory by deleting unused variables
    del labels_out, pixel_blob_mapping, branch_blob_mapping
    
    labels_out, N = cc3d.connected_components(binary_volume_copy, return_N=True)
    print(f"Number of blobs: {N}")
    
    # Reinitialize pixel_blob_mapping to reduce memory usage
    # Initialize a dictionary to map each branch ID to its corresponding blob(s)
    branch_blob_mapping = {}
    pixel_blob_mapping = np.zeros_like(labels_out, dtype=int)

    skel = Skeleton(binary_volume_copy)
    branch_data = summarize(skel)

    # Step 2: For each branch, get the coordinates and map them to the corresponding blob label(s)
    for branch_id in branch_data.index:
        # Get the coordinates of the current branch in the skeleton structure
        coordinates = skel.path_coordinates(branch_id)
        
        # Fetch the labels at those coordinates from the labels_out array
        branch_labels = labels_out[coordinates[:, 0], coordinates[:, 1], coordinates[:, 2]]
        
        # Find the unique label(s) associated with this branch
        unique_blob_labels = np.unique(branch_labels)
        
        # Store the unique label(s) in the branch_blob_mapping
        if len(unique_blob_labels) > 1:
            branch_blob_mapping[branch_id] = unique_blob_labels
        else:
            branch_blob_mapping[branch_id] = unique_blob_labels[0]
        
        # Step 3: Map each pixel in this branch to its corresponding blob label(s)
        for i, coord in enumerate(coordinates):
            pixel_blob_mapping[tuple(coord)] = branch_labels[i]
    
    if N == 2:
        print("All blobs are connected!")
        break

tiff.imwrite('C:/Users/nerea/Documents/MasterDTU/SpacialCourse_Fall24/specialCourse_fall24/outputs/connected_blobs_BOTTOM.tif', binary_volume_copy)
# Out:
# Number of LAbels: 32
# Connecting blobs 15 and 17
# Closest points: [54 68 55] in blob 15, [56 67 54] in blob 17
# Number of blobs: 31
# Connecting blobs 7 and 8
# Closest points: [ 37 117  20] in blob 7, [ 39 115  21] in blob 8
# Number of blobs: 30
# Connecting blobs 28 and 29
# Closest points: [94 14 91] in blob 28, [96 13 91] in blob 29
# Number of blobs: 29
# Connecting blobs 25 and 27
# Closest points: [89 11 99] in blob 25, [90 13 96] in blob 27
# Number of blobs: 28
# Connecting blobs 9 and 10
# Closest points: [ 44 107  24] in blob 9, [ 44 105  25] in blob 10
# Number of blobs: 27
# Connecting blobs 5 and 7
# Closest points: [ 36 119  19] in blob 5, [ 37 117  20] in blob 7
# Number of blobs: 26
# Connecting blobs 5 and 7
# Closest points: [ 39 115  21] in blob 5, [ 40 113  22] in blob 7
# Number of blobs: 25
# Connecting blobs 9 and 10
# Closest points: [ 48 100  26] in blob 9, [50 98 27] in blob 10
# Number of blobs: 24
# Connecting blobs 17 and 18
# Closest points: [76 51 61] in blob 17, [76 52 59] in blob 18
# Number of blobs: 23
# Connecting blobs 4 and 6
# Closest points: [ 35 126  13] in blob 4, [ 36 127  11] in blob 6
# Number of blobs: 22
# Connecting blobs 19 and 21
# Closest points: [90 13 96] in blob 19, [92 16 91] in blob 21
# Number of blobs: 21
# Connecting blobs 18 and 20
# Closest points: [87 23 86] in blob 18, [89 21 87] in blob 20
# Number of blobs: 20
# Connecting blobs 3 and 4
# Closest points: [ 32 126  15] in blob 3, [ 33 124  16] in blob 4
# Number of blobs: 19
# Connecting blobs 11 and 14
# Closest points: [66 57 61] in blob 11, [64 57 62] in blob 14
# Number of blobs: 18
# Connecting blobs 10 and 13
# Closest points: [62 70 45] in blob 10, [62 69 47] in blob 13
# Number of blobs: 17
# Connecting blobs 7 and 9
# Closest points: [53 94 28] in blob 7, [54 92 29] in blob 9
# Number of blobs: 16
# Connecting blobs 4 and 5
# Closest points: [ 41 112  23] in blob 4, [ 42 110  24] in blob 5
# Number of blobs: 15
# Connecting blobs 14 and 15
# Closest points: [96 13 91] in blob 14, [98 12 90] in blob 15
# Number of blobs: 14
# Connecting blobs 7 and 9
# Closest points: [56 67 54] in blob 7, [59 66 53] in blob 9
# Number of blobs: 13
# Connecting blobs 2 and 3
# Closest points: [ 23 135  14] in blob 2, [ 24 133  15] in blob 3
# Number of blobs: 12
# Connecting blobs 9 and 10
# Closest points: [78 47 64] in blob 9, [79 45 66] in blob 10
# Number of blobs: 11
# Connecting blobs 10 and 11
# Closest points: [90 18 90] in blob 10, [92 16 91] in blob 11
# Number of blobs: 10
# Connecting blobs 4 and 5
# Closest points: [46 87 43] in blob 4, [56 87 33] in blob 5
# Number of blobs: 9
# Connecting blobs 5 and 6
# Closest points: [62 67 49] in blob 5, [62 69 47] in blob 6
# Number of blobs: 8
# Connecting blobs 6 and 7
# Closest points: [60 51 76] in blob 6, [67 50 70] in blob 7
# Number of blobs: 7
# Connecting blobs 2 and 3
# Closest points: [ 34 122  17] in blob 2, [ 36 120  18] in blob 3
# Number of blobs: 6
# Connecting blobs 3 and 4
# Closest points: [56 87 33] in blob 3, [57 85 34] in blob 4
# Number of blobs: 5
# Connecting blobs 4 and 5
# Closest points: [83 30 81] in blob 4, [84 28 82] in blob 5
# Number of blobs: 4
# Connecting blobs 1 and 2
# Closest points: [ 14 144  11] in blob 1, [ 15 142  12] in blob 2
# Number of blobs: 3
# Connecting blobs 2 and 3
# Closest points: [74 56 57] in blob 2, [75 54 58] in blob 3
# Number of blobs: 2
# All blobs are connected!

# %% [markdown]
# ## BOTTOM - UNET

# %%
binary_volume = tiff.imread("C:/Users/nerea/Documents/MasterDTU/SpacialCourse_Fall24/specialCourse_fall24/outputs/FINAL/skeleleton_clean_x20_th5_UNET_BOTTOM.tif")

skel = Skeleton(binary_volume)
branch_data = summarize(skel)

labels_out = cc3d.connected_components(binary_volume)
labels_out, N = cc3d.connected_components(binary_volume, return_N=True)
print(f'Number of LAbels: {N}')

# Initialize a dictionary to map each branch ID to its corresponding blob(s)
branch_blob_mapping = {}
pixel_blob_mapping = np.zeros_like(labels_out, dtype=int)

# Step 2: For each branch, get the coordinates and map them to the corresponding blob label(s)
for branch_id in branch_data.index:
    # Get the coordinates of the current branch in the skeleton structure
    coordinates = skel.path_coordinates(branch_id)
    
    # Fetch the labels at those coordinates from the labels_out array
    branch_labels = labels_out[coordinates[:, 0], coordinates[:, 1], coordinates[:, 2]]
    
    # Find the unique label(s) associated with this branch
    unique_blob_labels = np.unique(branch_labels)
    
    # Store the unique label(s) in the branch_blob_mapping
    if len(unique_blob_labels) > 1:
        branch_blob_mapping[branch_id] = unique_blob_labels
    else:
        branch_blob_mapping[branch_id] = unique_blob_labels[0]
    
    # Step 3: Map each pixel in this branch to its corresponding blob label(s)
    for i, coord in enumerate(coordinates):
        pixel_blob_mapping[tuple(coord)] = branch_labels[i]


binary_volume_copy = np.copy(binary_volume)
while True:
    # Paso 4: Repetir los pasos 2 y 3 hasta que todos los blobs estén conectados
    binary_volume_copy = connect_blobs_3d(labels_out, pixel_blob_mapping, binary_volume_copy)
    
    # Free up memory by deleting unused variables
    del labels_out, pixel_blob_mapping, branch_blob_mapping
    
    labels_out, N = cc3d.connected_components(binary_volume_copy, return_N=True)
    print(f"Number of blobs: {N}")
    
    # Reinitialize pixel_blob_mapping to reduce memory usage
    # Initialize a dictionary to map each branch ID to its corresponding blob(s)
    branch_blob_mapping = {}
    pixel_blob_mapping = np.zeros_like(labels_out, dtype=int)

    skel = Skeleton(binary_volume_copy)
    branch_data = summarize(skel)

    # Step 2: For each branch, get the coordinates and map them to the corresponding blob label(s)
    for branch_id in branch_data.index:
        # Get the coordinates of the current branch in the skeleton structure
        coordinates = skel.path_coordinates(branch_id)
        
        # Fetch the labels at those coordinates from the labels_out array
        branch_labels = labels_out[coordinates[:, 0], coordinates[:, 1], coordinates[:, 2]]
        
        # Find the unique label(s) associated with this branch
        unique_blob_labels = np.unique(branch_labels)
        
        # Store the unique label(s) in the branch_blob_mapping
        if len(unique_blob_labels) > 1:
            branch_blob_mapping[branch_id] = unique_blob_labels
        else:
            branch_blob_mapping[branch_id] = unique_blob_labels[0]
        
        # Step 3: Map each pixel in this branch to its corresponding blob label(s)
        for i, coord in enumerate(coordinates):
            pixel_blob_mapping[tuple(coord)] = branch_labels[i]
    
    if N == 16:
        print("All blobs are connected!")
        break

tiff.imwrite('C:/Users/nerea/Documents/MasterDTU/SpacialCourse_Fall24/specialCourse_fall24/outputs/connected_blobs_UNET_BOTTOM.tif', binary_volume_copy)
# Out:
# Number of LAbels: 103
# Connecting blobs 95 and 96
# Closest points: [134  68 141] in blob 95, [134  70 141] in blob 96
# Number of blobs: 102
# Connecting blobs 57 and 58
# Closest points: [ 85 132 117] in blob 57, [ 85 134 116] in blob 58
# Number of blobs: 101
# Connecting blobs 33 and 34
# Closest points: [ 68 140  88] in blob 33, [ 69 140  86] in blob 34
# Number of blobs: 100
# Connecting blobs 68 and 70
# Closest points: [ 93  41 102] in blob 68, [ 94  42 104] in blob 70
# Number of blobs: 99
# Connecting blobs 98 and 99
# Closest points: [157   1 195] in blob 98, [160   1 195] in blob 99
# Number of blobs: 98
# Connecting blobs 51 and 56
# Closest points: [ 82 132 118] in blob 51, [ 85 132 117] in blob 56
# Number of blobs: 97
# Connecting blobs 76 and 78
# Closest points: [106  18  80] in blob 76, [108  20  78] in blob 78
# Number of blobs: 96
# Connecting blobs 33 and 37
# Closest points: [ 68 142  88] in blob 33, [ 70 143  88] in blob 37
# Number of blobs: 95
# Connecting blobs 62 and 66
# Closest points: [93 46 99] in blob 62, [ 94  44 101] in blob 66
# Number of blobs: 94
# Connecting blobs 88 and 89
# Closest points: [134  70 141] in blob 88, [136  71 141] in blob 89
# Number of blobs: 93
# Connecting blobs 49 and 52
# Closest points: [ 82 100  85] in blob 49, [ 84 100  82] in blob 52
# Number of blobs: 92
# Connecting blobs 30 and 36
# Closest points: [68 57 60] in blob 30, [70 54 61] in blob 36
# Number of blobs: 91
# Connecting blobs 33 and 35
# Closest points: [ 70 138  89] in blob 33, [ 70 140  91] in blob 35
# Number of blobs: 90
# Connecting blobs 8 and 9
# Closest points: [ 26 132  15] in blob 8, [ 28 131  15] in blob 9
# Number of blobs: 89
# Connecting blobs 5 and 6
# Closest points: [ 17 140  12] in blob 5, [ 19 139  12] in blob 6
# Number of blobs: 88
# Connecting blobs 11 and 13
# Closest points: [ 37 196   3] in blob 11, [ 39 194   5] in blob 13
# Number of blobs: 87
# Connecting blobs 2 and 3
# Closest points: [  8 154   9] in blob 2, [ 11 152   8] in blob 3
# Number of blobs: 85
# Connecting blobs 28 and 29
# Closest points: [ 69 142  85] in blob 28, [ 69 141  83] in blob 29
# Number of blobs: 84
# Connecting blobs 55 and 58
# Closest points: [91 72 80] in blob 55, [96 72 79] in blob 58
# Number of blobs: 83
# Connecting blobs 74 and 76
# Closest points: [121  37 119] in blob 74, [123  37 121] in blob 76
# Number of blobs: 82
# Connecting blobs 80 and 81
# Closest points: [148  38 151] in blob 80, [149  35 151] in blob 81
# Number of blobs: 81
# Connecting blobs 73 and 74
# Closest points: [119  32 120] in blob 73, [120  34 119] in blob 74
# Number of blobs: 80
# Connecting blobs 32 and 33
# Closest points: [74 45 71] in blob 32, [75 47 66] in blob 33
# Number of blobs: 79
# Connecting blobs 58 and 64
# Closest points: [106   8  89] in blob 58, [108   7  90] in blob 64
# Number of blobs: 78
# Connecting blobs 60 and 62
# Closest points: [103  87 107] in blob 60, [105  86 109] in blob 62
# Number of blobs: 77
# Connecting blobs 24 and 25
# Closest points: [68 53 65] in blob 24, [69 55 61] in blob 25
# Number of blobs: 76
# Connecting blobs 41 and 44
# Closest points: [ 82 148 110] in blob 41, [ 85 143 112] in blob 44
# Number of blobs: 75
# Connecting blobs 72 and 73
# Closest points: [140  41 140] in blob 72, [143  39 143] in blob 73
# Number of blobs: 74
# Connecting blobs 57 and 60
# Closest points: [105  17  82] in blob 57, [106  18  80] in blob 60
# Number of blobs: 73
# Connecting blobs 24 and 29
# Closest points: [70 57 58] in blob 24, [72 56 57] in blob 29
# Number of blobs: 72
# Connecting blobs 6 and 8
# Closest points: [ 35 125  13] in blob 6, [ 37 125  11] in blob 8
# Number of blobs: 71
# Connecting blobs 0 and 53
# Closest points: [ 97  95 105] in blob 0, [ 98  95 105] in blob 53
# Number of blobs: 71
# Connecting blobs 47 and 53
# Closest points: [ 91  97 105] in blob 47, [ 97  95 105] in blob 53
# Number of blobs: 70
# Connecting blobs 40 and 45
# Closest points: [ 84 117  88] in blob 40, [ 88 112  92] in blob 45
# Number of blobs: 69
# Connecting blobs 47 and 55
# Closest points: [102  42 101] in blob 47, [104  43 101] in blob 55
# Number of blobs: 68
# Connecting blobs 61 and 63
# Closest points: [117  72 121] in blob 61, [121  69 125] in blob 63
# Number of blobs: 67
# Connecting blobs 13 and 15
# Closest points: [58 77 41] in blob 13, [56 77 42] in blob 15
# Number of blobs: 66
# Connecting blobs 2 and 3
# Closest points: [ 16 142  12] in blob 2, [ 17 140  12] in blob 3
# Number of blobs: 65
# Connecting blobs 36 and 42
# Closest points: [ 85 133 118] in blob 36, [ 88 133 119] in blob 42
# Number of blobs: 64
# Connecting blobs 0 and 43
# Closest points: [ 88  98 110] in blob 0, [ 89  98 110] in blob 43
# Number of blobs: 64
# Connecting blobs 25 and 29
# Closest points: [71 97 25] in blob 25, [76 90 29] in blob 29
# Number of blobs: 63
# Connecting blobs 8 and 9
# Closest points: [ 40 113  22] in blob 8, [ 42 111  23] in blob 9
# Number of blobs: 62
# Connecting blobs 13 and 17
# Closest points: [ 58  45 131] in blob 13, [ 64  51 131] in blob 17
# Number of blobs: 61
# Connecting blobs 0 and 39
# Closest points: [ 87  98 110] in blob 0, [ 88  98 110] in blob 39
# Number of blobs: 61
# Connecting blobs 0 and 39
# Closest points: [ 86  98 110] in blob 0, [ 87  98 110] in blob 39
# Number of blobs: 61
# Connecting blobs 27 and 43
# Closest points: [91 72 82] in blob 27, [91 72 80] in blob 43
# Number of blobs: 60
# Connecting blobs 0 and 38
# Closest points: [ 85  98 110] in blob 0, [ 86  98 110] in blob 38
# Number of blobs: 60
# Connecting blobs 0 and 37
# Closest points: [ 84  98 110] in blob 0, [ 85  98 110] in blob 37
# Number of blobs: 60
# Connecting blobs 0 and 35
# Closest points: [ 83  98 110] in blob 0, [ 84  98 110] in blob 35
# Number of blobs: 60
# Connecting blobs 49 and 50
# Closest points: [114  55 146] in blob 49, [112  57 146] in blob 50
# Number of blobs: 59
# Connecting blobs 30 and 37
# Closest points: [84 28 82] in blob 30, [85 26 84] in blob 37
# Number of blobs: 58
# Connecting blobs 6 and 8
# Closest points: [ 38 115  32] in blob 6, [ 41 112  23] in blob 8
# Number of blobs: 57
# Connecting blobs 46 and 52
# Closest points: [115  36 113] in blob 46, [117  36 115] in blob 52
# Number of blobs: 56
# Connecting blobs 0 and 34
# Closest points: [ 82  98 110] in blob 0, [ 83  98 110] in blob 34
# Number of blobs: 56
# Connecting blobs 54 and 55
# Closest points: [143  40 144] in blob 54, [148  38 150] in blob 55
# Number of blobs: 55
# Connecting blobs 3 and 4
# Closest points: [ 24 124  23] in blob 3, [ 27 131  15] in blob 4
# Number of blobs: 54
# Connecting blobs 3 and 4
# Closest points: [ 29 130  15] in blob 3, [ 30 128  15] in blob 4
# Number of blobs: 53
# Connecting blobs 0 and 29
# Closest points: [ 81  98 110] in blob 0, [ 82  98 110] in blob 29
# Number of blobs: 53
# Connecting blobs 0 and 28
# Closest points: [ 80  98 110] in blob 0, [ 81  98 110] in blob 28
# Number of blobs: 53
# Connecting blobs 41 and 42
# Closest points: [100  10  91] in blob 41, [100  16  85] in blob 42
# Number of blobs: 52
# Connecting blobs 35 and 41
# Closest points: [98 11 91] in blob 35, [100  10  91] in blob 41
# Number of blobs: 51
# Connecting blobs 0 and 27
# Closest points: [ 79  98 110] in blob 0, [ 80  98 110] in blob 27
# Number of blobs: 51
# Connecting blobs 0 and 39
# Closest points: [91 87 88] in blob 0, [92 87 88] in blob 39
# Number of blobs: 51
# Connecting blobs 0 and 27
# Closest points: [ 78  98 110] in blob 0, [ 79  98 110] in blob 27
# Number of blobs: 51
# Connecting blobs 0 and 41
# Closest points: [ 99  92 105] in blob 0, [100  92 105] in blob 41
# Number of blobs: 51
# Connecting blobs 0 and 41
# Closest points: [ 98  92 105] in blob 0, [ 99  92 105] in blob 41
# Number of blobs: 51
# Connecting blobs 0 and 41
# Closest points: [ 97  92 105] in blob 0, [ 98  92 105] in blob 41
# Number of blobs: 51
# Connecting blobs 0 and 41
# Closest points: [ 96  92 105] in blob 0, [ 97  92 105] in blob 41
# Number of blobs: 51
# Connecting blobs 0 and 41
# Closest points: [ 95  92 105] in blob 0, [ 96  92 105] in blob 41
# Number of blobs: 51
# Connecting blobs 0 and 41
# Closest points: [ 94  92 105] in blob 0, [ 95  92 105] in blob 41
# Number of blobs: 51
# Connecting blobs 0 and 41
# Closest points: [ 93  92 105] in blob 0, [ 94  92 105] in blob 41
# Number of blobs: 51
# Connecting blobs 0 and 41
# Closest points: [ 92  92 105] in blob 0, [ 93  92 105] in blob 41
# Number of blobs: 51
# Connecting blobs 0 and 40
# Closest points: [ 91  92 105] in blob 0, [ 92  92 105] in blob 40
# Number of blobs: 51
# Connecting blobs 0 and 40
# Closest points: [ 90  92 105] in blob 0, [ 91  92 105] in blob 40
# Number of blobs: 51
# Connecting blobs 0 and 38
# Closest points: [ 89  92 105] in blob 0, [ 90  92 105] in blob 38
# Number of blobs: 51
# Connecting blobs 27 and 37
# Closest points: [ 96  95 105] in blob 27, [ 96  92 105] in blob 37
# Number of blobs: 50
# Connecting blobs 0 and 27
# Closest points: [ 77  98 110] in blob 0, [ 78  98 110] in blob 27
# Number of blobs: 50
# Connecting blobs 0 and 27
# Closest points: [ 76  98 110] in blob 0, [ 77  98 110] in blob 27
# Number of blobs: 50
# Connecting blobs 0 and 25
# Closest points: [ 75  98 110] in blob 0, [ 76  98 110] in blob 25
# Number of blobs: 50
# Connecting blobs 0 and 23
# Closest points: [ 74  98 110] in blob 0, [ 75  98 110] in blob 23
# Number of blobs: 50
# Connecting blobs 0 and 23
# Closest points: [ 73  98 110] in blob 0, [ 74  98 110] in blob 23
# Number of blobs: 50
# Connecting blobs 0 and 22
# Closest points: [ 72  98 110] in blob 0, [ 73  98 110] in blob 22
# Number of blobs: 50
# Connecting blobs 0 and 21
# Closest points: [ 71  98 110] in blob 0, [ 72  98 110] in blob 21
# Number of blobs: 50
# Connecting blobs 0 and 21
# Closest points: [ 70  98 110] in blob 0, [ 71  98 110] in blob 21
# Number of blobs: 50
# Connecting blobs 0 and 20
# Closest points: [ 69  98 110] in blob 0, [ 70  98 110] in blob 20
# Number of blobs: 50
# Connecting blobs 26 and 32
# Closest points: [ 76 155 111] in blob 26, [ 82 148 110] in blob 32
# Number of blobs: 49
# Connecting blobs 18 and 19
# Closest points: [ 68 143  93] in blob 18, [ 69 140  91] in blob 19
# Number of blobs: 48
# Connecting blobs 12 and 20
# Closest points: [63 88 25] in blob 12, [72 95 26] in blob 20
# Number of blobs: 47
# Connecting blobs 0 and 36
# Closest points: [90 87 88] in blob 0, [91 87 88] in blob 36
# Number of blobs: 47
# Connecting blobs 0 and 19
# Closest points: [ 68  98 110] in blob 0, [ 69  98 110] in blob 19
# Number of blobs: 47
# Connecting blobs 13 and 16
# Closest points: [63 53 69] in blob 13, [68 53 65] in blob 16
# Number of blobs: 46
# Connecting blobs 0 and 34
# Closest points: [89 87 88] in blob 0, [90 87 88] in blob 34
# Number of blobs: 46
# Connecting blobs 0 and 16
# Closest points: [ 67  98 110] in blob 0, [ 68  98 110] in blob 16
# Number of blobs: 46
# Connecting blobs 37 and 40
# Closest points: [117  30 120] in blob 37, [117  28 121] in blob 40
# Number of blobs: 45
# Connecting blobs 0 and 15
# Closest points: [ 66  98 110] in blob 0, [ 67  98 110] in blob 15
# Number of blobs: 45
# Connecting blobs 0 and 33
# Closest points: [88 87 88] in blob 0, [89 87 88] in blob 33
# Number of blobs: 45
# Connecting blobs 0 and 14
# Closest points: [ 65  98 110] in blob 0, [ 66  98 110] in blob 14
# Number of blobs: 45
# Connecting blobs 0 and 32
# Closest points: [87 87 88] in blob 0, [88 87 88] in blob 32
# Number of blobs: 45
# Connecting blobs 40 and 41
# Closest points: [115  63 113] in blob 40, [117  72 121] in blob 41
# Number of blobs: 44
# Connecting blobs 0 and 14
# Closest points: [ 64  98 110] in blob 0, [ 65  98 110] in blob 14
# Number of blobs: 44
# Connecting blobs 0 and 32
# Closest points: [86 87 88] in blob 0, [87 87 88] in blob 32
# Number of blobs: 44
# Connecting blobs 0 and 14
# Closest points: [ 63  98 110] in blob 0, [ 64  98 110] in blob 14
# Number of blobs: 44
# Connecting blobs 0 and 31
# Closest points: [85 87 88] in blob 0, [86 87 88] in blob 31
# Number of blobs: 44
# Connecting blobs 13 and 20
# Closest points: [78 50 61] in blob 13, [77 49 63] in blob 20
# Number of blobs: 43
# Connecting blobs 0 and 14
# Closest points: [ 62  98 110] in blob 0, [ 63  98 110] in blob 14
# Number of blobs: 43
# Connecting blobs 0 and 29
# Closest points: [84 87 88] in blob 0, [85 87 88] in blob 29
# Number of blobs: 43
# Connecting blobs 0 and 13
# Closest points: [ 61  98 110] in blob 0, [ 62  98 110] in blob 13
# Number of blobs: 43
# Connecting blobs 0 and 28
# Closest points: [83 87 88] in blob 0, [84 87 88] in blob 28
# Number of blobs: 43
# Connecting blobs 26 and 28
# Closest points: [ 82 100  85] in blob 26, [83 87 88] in blob 28
# Number of blobs: 42
# Connecting blobs 0 and 13
# Closest points: [ 60  98 110] in blob 0, [ 61  98 110] in blob 13
# Number of blobs: 42
# Connecting blobs 10 and 11
# Closest points: [ 64  53 129] in blob 10, [ 58  59 122] in blob 11
# Number of blobs: 41
# Connecting blobs 0 and 12
# Closest points: [ 59  98 110] in blob 0, [ 60  98 110] in blob 12
# Number of blobs: 41
# Connecting blobs 28 and 29
# Closest points: [91 15 93] in blob 28, [91 16 91] in blob 29
# Number of blobs: 40
# Connecting blobs 0 and 11
# Closest points: [ 58  98 110] in blob 0, [ 59  98 110] in blob 11
# Number of blobs: 40
# Connecting blobs 0 and 11
# Closest points: [ 57  98 110] in blob 0, [ 58  98 110] in blob 11
# Number of blobs: 40
# Connecting blobs 15 and 16
# Closest points: [ 67 134  68] in blob 15, [ 68 131  78] in blob 16
# Number of blobs: 39
# Connecting blobs 0 and 10
# Closest points: [ 56  98 110] in blob 0, [ 57  98 110] in blob 10
# Number of blobs: 39
# Connecting blobs 36 and 38
# Closest points: [136  40 135] in blob 36, [140  40 139] in blob 38
# Number of blobs: 38
# Connecting blobs 29 and 30
# Closest points: [102  29 112] in blob 29, [101  28 114] in blob 30
# Number of blobs: 37
# Connecting blobs 0 and 10
# Closest points: [ 55  98 110] in blob 0, [ 56  98 110] in blob 10
# Number of blobs: 37
# Connecting blobs 1 and 2
# Closest points: [ 12 150   9] in blob 1, [ 12 148  10] in blob 2
# Number of blobs: 36
# Connecting blobs 0 and 9
# Closest points: [ 54  98 110] in blob 0, [ 55  98 110] in blob 9
# Number of blobs: 36
# Connecting blobs 0 and 23
# Closest points: [81 94 86] in blob 0, [82 94 86] in blob 23
# Number of blobs: 36
# Connecting blobs 0 and 22
# Closest points: [80 94 86] in blob 0, [81 94 86] in blob 22
# Number of blobs: 36
# Connecting blobs 0 and 9
# Closest points: [ 53  98 110] in blob 0, [ 54  98 110] in blob 9
# Number of blobs: 36
# Connecting blobs 0 and 21
# Closest points: [79 94 86] in blob 0, [80 94 86] in blob 21
# Number of blobs: 36
# Connecting blobs 0 and 21
# Closest points: [78 94 86] in blob 0, [79 94 86] in blob 21
# Number of blobs: 36
# Connecting blobs 0 and 9
# Closest points: [ 52  98 110] in blob 0, [ 53  98 110] in blob 9
# Number of blobs: 36
# Connecting blobs 0 and 21
# Closest points: [77 94 86] in blob 0, [78 94 86] in blob 21
# Number of blobs: 36
# Connecting blobs 0 and 21
# Closest points: [76 94 86] in blob 0, [77 94 86] in blob 21
# Number of blobs: 36
# Connecting blobs 0 and 18
# Closest points: [75 94 86] in blob 0, [76 94 86] in blob 18
# Number of blobs: 36
# Connecting blobs 0 and 9
# Closest points: [ 51  98 110] in blob 0, [ 52  98 110] in blob 9
# Number of blobs: 36
# Connecting blobs 0 and 17
# Closest points: [74 94 86] in blob 0, [75 94 86] in blob 17
# Number of blobs: 36
# Connecting blobs 24 and 27
# Closest points: [ 87 118 127] in blob 24, [ 88 112 130] in blob 27
# Number of blobs: 35
# Connecting blobs 0 and 17
# Closest points: [73 94 86] in blob 0, [74 94 86] in blob 17
# Number of blobs: 35
# Connecting blobs 0 and 9
# Closest points: [ 50  98 110] in blob 0, [ 51  98 110] in blob 9
# Number of blobs: 35
# Connecting blobs 16 and 18
# Closest points: [ 72 120  49] in blob 16, [ 75 128  51] in blob 18
# Number of blobs: 34
# Connecting blobs 0 and 17
# Closest points: [72 94 86] in blob 0, [73 94 86] in blob 17
# Number of blobs: 34
# Connecting blobs 2 and 3
# Closest points: [ 37 116  21] in blob 2, [ 39 115  21] in blob 3
# Number of blobs: 33
# Connecting blobs 0 and 8
# Closest points: [ 49  98 110] in blob 0, [ 50  98 110] in blob 8
# Number of blobs: 33
# Connecting blobs 0 and 15
# Closest points: [71 94 86] in blob 0, [72 94 86] in blob 15
# Number of blobs: 33
# Connecting blobs 0 and 15
# Closest points: [70 94 86] in blob 0, [71 94 86] in blob 15
# Number of blobs: 33
# Connecting blobs 28 and 32
# Closest points: [124  68 141] in blob 28, [134  68 141] in blob 32
# Number of blobs: 32
# Connecting blobs 0 and 8
# Closest points: [ 48  98 110] in blob 0, [ 49  98 110] in blob 8
# Number of blobs: 32
# Connecting blobs 0 and 15
# Closest points: [69 94 86] in blob 0, [70 94 86] in blob 15
# Number of blobs: 32
# Connecting blobs 13 and 14
# Closest points: [ 69 138  82] in blob 13, [ 69 140  83] in blob 14
# Number of blobs: 31
# Connecting blobs 6 and 14
# Closest points: [ 92  97 101] in blob 6, [92 98 99] in blob 14
# Number of blobs: 30
# Connecting blobs 0 and 6
# Closest points: [ 47  98 110] in blob 0, [ 48  98 110] in blob 6
# Number of blobs: 30
# Connecting blobs 0 and 6
# Closest points: [ 46  98 110] in blob 0, [ 47  98 110] in blob 6
# Number of blobs: 30
# Connecting blobs 0 and 6
# Closest points: [ 45  98 110] in blob 0, [ 46  98 110] in blob 6
# Number of blobs: 30
# Connecting blobs 0 and 4
# Closest points: [ 44  98 110] in blob 0, [ 45  98 110] in blob 4
# Number of blobs: 30
# Connecting blobs 0 and 4
# Closest points: [ 43  98 110] in blob 0, [ 44  98 110] in blob 4
# Number of blobs: 30
# Connecting blobs 0 and 4
# Closest points: [ 42  98 110] in blob 0, [ 43  98 110] in blob 4
# Number of blobs: 30
# Connecting blobs 0 and 4
# Closest points: [ 41  98 110] in blob 0, [ 42  98 110] in blob 4
# Number of blobs: 30
# Connecting blobs 0 and 4
# Closest points: [ 40  98 110] in blob 0, [ 41  98 110] in blob 4
# Number of blobs: 30
# Connecting blobs 0 and 4
# Closest points: [ 39  98 110] in blob 0, [ 40  98 110] in blob 4
# Number of blobs: 30
# Connecting blobs 0 and 4
# Closest points: [ 38  98 110] in blob 0, [ 39  98 110] in blob 4
# Number of blobs: 30
# Connecting blobs 0 and 4
# Closest points: [ 37  98 110] in blob 0, [ 38  98 110] in blob 4
# Number of blobs: 30
# Connecting blobs 5 and 6
# Closest points: [ 46  83 107] in blob 5, [ 46  89 106] in blob 6
# Number of blobs: 29
# Connecting blobs 0 and 3
# Closest points: [ 36  98 110] in blob 0, [ 37  98 110] in blob 3
# Number of blobs: 29
# Connecting blobs 14 and 23
# Closest points: [93 77 78] in blob 14, [93 83 72] in blob 23
# Number of blobs: 28
# Connecting blobs 0 and 3
# Closest points: [ 35  98 110] in blob 0, [ 36  98 110] in blob 3
# Number of blobs: 28
# Connecting blobs 24 and 26
# Closest points: [124  66 131] in blob 24, [121  68 125] in blob 26
# Number of blobs: 27
# Connecting blobs 0 and 3
# Closest points: [ 34  98 110] in blob 0, [ 35  98 110] in blob 3
# Number of blobs: 27
# Connecting blobs 0 and 3
# Closest points: [ 33  98 110] in blob 0, [ 34  98 110] in blob 3
# Number of blobs: 27
# Connecting blobs 0 and 3
# Closest points: [ 32  98 110] in blob 0, [ 33  98 110] in blob 3
# Number of blobs: 27
# Connecting blobs 0 and 20
# Closest points: [ 83 117  88] in blob 0, [ 84 117  88] in blob 20
# Number of blobs: 27
# Connecting blobs 0 and 3
# Closest points: [ 31  98 110] in blob 0, [ 32  98 110] in blob 3
# Number of blobs: 27
# Connecting blobs 0 and 3
# Closest points: [ 30  98 110] in blob 0, [ 31  98 110] in blob 3
# Number of blobs: 27
# Connecting blobs 6 and 9
# Closest points: [58 89 29] in blob 6, [60 88 28] in blob 9
# Number of blobs: 26
# Connecting blobs 0 and 19
# Closest points: [ 82 117  88] in blob 0, [ 83 117  88] in blob 19
# Number of blobs: 26
# Connecting blobs 0 and 3
# Closest points: [ 29  98 110] in blob 0, [ 30  98 110] in blob 3
# Number of blobs: 26
# Connecting blobs 6 and 7
# Closest points: [52 94 29] in blob 6, [49 95 42] in blob 7
# Number of blobs: 25
# Connecting blobs 0 and 3
# Closest points: [ 28  98 110] in blob 0, [ 29  98 110] in blob 3
# Number of blobs: 25
# Connecting blobs 0 and 17
# Closest points: [ 81 117  88] in blob 0, [ 82 117  88] in blob 17
# Number of blobs: 25
# Connecting blobs 0 and 3
# Closest points: [ 27  98 110] in blob 0, [ 28  98 110] in blob 3
# Number of blobs: 25
# Connecting blobs 0 and 3
# Closest points: [ 26  98 110] in blob 0, [ 27  98 110] in blob 3
# Number of blobs: 25
# Connecting blobs 0 and 16
# Closest points: [ 80 117  88] in blob 0, [ 81 117  88] in blob 16
# Number of blobs: 25
# Connecting blobs 0 and 3
# Closest points: [ 25  98 110] in blob 0, [ 26  98 110] in blob 3
# Number of blobs: 25
# Connecting blobs 10 and 15
# Closest points: [ 76 112  83] in blob 10, [ 80 117  88] in blob 15
# Number of blobs: 24
# Connecting blobs 0 and 3
# Closest points: [ 24  98 110] in blob 0, [ 25  98 110] in blob 3
# Number of blobs: 24
# Connecting blobs 15 and 18
# Closest points: [87 23 86] in blob 15, [88 21 87] in blob 18
# Number of blobs: 23
# Connecting blobs 18 and 19
# Closest points: [106  35 108] in blob 18, [108  35 109] in blob 19
# Number of blobs: 22
# Connecting blobs 0 and 2
# Closest points: [ 23  98 110] in blob 0, [ 24  98 110] in blob 2
# Number of blobs: 22
# Connecting blobs 0 and 2
# Closest points: [ 22  98 110] in blob 0, [ 23  98 110] in blob 2
# Number of blobs: 22
# Connecting blobs 0 and 2
# Closest points: [ 21  98 110] in blob 0, [ 22  98 110] in blob 2
# Number of blobs: 22
# Connecting blobs 6 and 16
# Closest points: [80 63 41] in blob 6, [82 65 34] in blob 16
# Number of blobs: 21
# Connecting blobs 0 and 2
# Closest points: [ 20  98 110] in blob 0, [ 21  98 110] in blob 2
# Number of blobs: 21
# Connecting blobs 0 and 2
# Closest points: [ 19  98 110] in blob 0, [ 20  98 110] in blob 2
# Number of blobs: 21
# Connecting blobs 0 and 2
# Closest points: [ 18  98 110] in blob 0, [ 19  98 110] in blob 2
# Number of blobs: 21
# Connecting blobs 0 and 2
# Closest points: [ 17  98 110] in blob 0, [ 18  98 110] in blob 2
# Number of blobs: 21
# Connecting blobs 0 and 2
# Closest points: [ 16  98 110] in blob 0, [ 17  98 110] in blob 2
# Number of blobs: 21
# Connecting blobs 9 and 11
# Closest points: [ 66 101  76] in blob 9, [ 75 100  63] in blob 11
# Number of blobs: 20
# Connecting blobs 0 and 2
# Closest points: [ 15  98 110] in blob 0, [ 16  98 110] in blob 2
# Number of blobs: 20
# Connecting blobs 17 and 18
# Closest points: [116  86 139] in blob 17, [114  87 140] in blob 18
# Number of blobs: 19
# Connecting blobs 2 and 5
# Closest points: [ 46  98 110] in blob 2, [ 46  96 102] in blob 5
# Number of blobs: 18
# Connecting blobs 11 and 14
# Closest points: [ 85 143 112] in blob 11, [ 88 138 117] in blob 14
# Number of blobs: 17
# Connecting blobs 15 and 16
# Closest points: [126  38 124] in blob 15, [128  38 126] in blob 16
# Number of blobs: 16
# All blobs are connected!

# %% [markdown]
# ## TOP - GT

# %%
binary_volume = tiff.imread("C:/Users/nerea/Documents/MasterDTU/SpacialCourse_Fall24/specialCourse_fall24/outputs/FINAL/skeleleton_clean_x20_th5_TOP.tif")

skel = Skeleton(binary_volume)
branch_data = summarize(skel)

labels_out = cc3d.connected_components(binary_volume)
labels_out, N = cc3d.connected_components(binary_volume, return_N=True)
print(f'Number of LAbels: {N}')

# Initialize a dictionary to map each branch ID to its corresponding blob(s)
branch_blob_mapping = {}
pixel_blob_mapping = np.zeros_like(labels_out, dtype=int)

# Step 2: For each branch, get the coordinates and map them to the corresponding blob label(s)
for branch_id in branch_data.index:
    # Get the coordinates of the current branch in the skeleton structure
    coordinates = skel.path_coordinates(branch_id)
    
    # Fetch the labels at those coordinates from the labels_out array
    branch_labels = labels_out[coordinates[:, 0], coordinates[:, 1], coordinates[:, 2]]
    
    # Find the unique label(s) associated with this branch
    unique_blob_labels = np.unique(branch_labels)
    
    # Store the unique label(s) in the branch_blob_mapping
    if len(unique_blob_labels) > 1:
        branch_blob_mapping[branch_id] = unique_blob_labels
    else:
        branch_blob_mapping[branch_id] = unique_blob_labels[0]
    
    # Step 3: Map each pixel in this branch to its corresponding blob label(s)
    for i, coord in enumerate(coordinates):
        pixel_blob_mapping[tuple(coord)] = branch_labels[i]


binary_volume_copy = np.copy(binary_volume)
while True:
    # Paso 4: Repetir los pasos 2 y 3 hasta que todos los blobs estén conectados
    binary_volume_copy = connect_blobs_3d(labels_out, pixel_blob_mapping, binary_volume_copy)
    
    # Free up memory by deleting unused variables
    del labels_out, pixel_blob_mapping, branch_blob_mapping
    
    labels_out, N = cc3d.connected_components(binary_volume_copy, return_N=True)
    print(f"Number of blobs: {N}")
    
    # Reinitialize pixel_blob_mapping to reduce memory usage
    # Initialize a dictionary to map each branch ID to its corresponding blob(s)
    branch_blob_mapping = {}
    pixel_blob_mapping = np.zeros_like(labels_out, dtype=int)

    skel = Skeleton(binary_volume_copy)
    branch_data = summarize(skel)

    # Step 2: For each branch, get the coordinates and map them to the corresponding blob label(s)
    for branch_id in branch_data.index:
        # Get the coordinates of the current branch in the skeleton structure
        coordinates = skel.path_coordinates(branch_id)
        
        # Fetch the labels at those coordinates from the labels_out array
        branch_labels = labels_out[coordinates[:, 0], coordinates[:, 1], coordinates[:, 2]]
        
        # Find the unique label(s) associated with this branch
        unique_blob_labels = np.unique(branch_labels)
        
        # Store the unique label(s) in the branch_blob_mapping
        if len(unique_blob_labels) > 1:
            branch_blob_mapping[branch_id] = unique_blob_labels
        else:
            branch_blob_mapping[branch_id] = unique_blob_labels[0]
        
        # Step 3: Map each pixel in this branch to its corresponding blob label(s)
        for i, coord in enumerate(coordinates):
            pixel_blob_mapping[tuple(coord)] = branch_labels[i]
    
    if N == 3:
        print("All blobs are connected!")
        break

tiff.imwrite('C:/Users/nerea/Documents/MasterDTU/SpacialCourse_Fall24/specialCourse_fall24/outputs/connected_blobs_TOP.tif', binary_volume_copy)
# Out:
# Number of LAbels: 29
# Connecting blobs 21 and 23
# Closest points: [390 111  32] in blob 21, [392 112  33] in blob 23
# Number of blobs: 28
# Connecting blobs 2 and 3
# Closest points: [211 149 199] in blob 2, [211 147 199] in blob 3
# Number of blobs: 27
# Connecting blobs 10 and 13
# Closest points: [321 194  16] in blob 10, [322 192  15] in blob 13
# Number of blobs: 26
# Connecting blobs 20 and 22
# Closest points: [394  25 165] in blob 20, [395  23 165] in blob 22
# Number of blobs: 25
# Connecting blobs 10 and 12
# Closest points: [321 183   8] in blob 10, [322 181   8] in blob 12
# Number of blobs: 24
# Connecting blobs 20 and 23
# Closest points: [398   7  93] in blob 20, [398  20  93] in blob 23
# Number of blobs: 23
# Connecting blobs 1 and 2
# Closest points: [193 171 191] in blob 1, [205 163 194] in blob 2
# Number of blobs: 22
# Connecting blobs 10 and 14
# Closest points: [349  47 104] in blob 10, [351  45 104] in blob 14
# Number of blobs: 21
# Connecting blobs 18 and 20
# Closest points: [398   9  93] in blob 18, [398   9 123] in blob 20
# Number of blobs: 20
# Connecting blobs 16 and 20
# Closest points: [392 110  38] in blob 16, [399  85  48] in blob 20
# Number of blobs: 19
# Connecting blobs 15 and 17
# Closest points: [384  10 195] in blob 15, [399  17 168] in blob 17
# Number of blobs: 18
# Connecting blobs 3 and 4
# Closest points: [239 161 138] in blob 3, [240 161 136] in blob 4
# Number of blobs: 17
# Connecting blobs 16 and 17
# Closest points: [399  34  97] in blob 16, [398  46  93] in blob 17
# Number of blobs: 16
# Connecting blobs 10 and 13
# Closest points: [342 140  74] in blob 10, [363 136  64] in blob 13
# Number of blobs: 15
# Connecting blobs 4 and 7
# Closest points: [267 184 109] in blob 4, [298 175  93] in blob 7
# Number of blobs: 14
# Connecting blobs 1 and 2
# Closest points: [205 163 194] in blob 1, [206 163 192] in blob 2
# Number of blobs: 13
# Connecting blobs 1 and 2
# Closest points: [210 189 179] in blob 1, [209 188 177] in blob 2
# Number of blobs: 12
# Connecting blobs 3 and 4
# Closest points: [300 150 150] in blob 3, [312 161 161] in blob 4
# Number of blobs: 11
# Connecting blobs 4 and 7
# Closest points: [318 195  18] in blob 4, [331 197  51] in blob 7
# Number of blobs: 10
# Connecting blobs 6 and 9
# Closest points: [392 111  40] in blob 6, [392 110  38] in blob 9
# Number of blobs: 9
# Connecting blobs 5 and 9
# Closest points: [380  47  78] in blob 5, [397  51  88] in blob 9
# Number of blobs: 8
# Connecting blobs 7 and 8
# Closest points: [334  53 197] in blob 7, [388  37 172] in blob 8
# Number of blobs: 7
# Connecting blobs 4 and 6
# Closest points: [343 157  58] in blob 4, [342 155  58] in blob 6
# Number of blobs: 6
# Connecting blobs 5 and 6
# Closest points: [365  42 145] in blob 5, [379  40 176] in blob 6
# Number of blobs: 5
# Connecting blobs 2 and 4
# Closest points: [293 198  72] in blob 2, [331 197  51] in blob 4
# Number of blobs: 4
# Connecting blobs 1 and 3
# Closest points: [243 162 125] in blob 1, [276 182 130] in blob 3
# Number of blobs: 3
# All blobs are connected!

# %% [markdown]
# ## TOP - UNET

# %%
binary_volume = tiff.imread("C:/Users/nerea/Documents/MasterDTU/SpacialCourse_Fall24/specialCourse_fall24/outputs/FINAL/skeleleton_clean_x20_th5_UNET_TOP.tif")

skel = Skeleton(binary_volume)
branch_data = summarize(skel)

labels_out = cc3d.connected_components(binary_volume)
labels_out, N = cc3d.connected_components(binary_volume, return_N=True)
print(f'Number of LAbels: {N}')

# Initialize a dictionary to map each branch ID to its corresponding blob(s)
branch_blob_mapping = {}
pixel_blob_mapping = np.zeros_like(labels_out, dtype=int)

# Step 2: For each branch, get the coordinates and map them to the corresponding blob label(s)
for branch_id in branch_data.index:
    # Get the coordinates of the current branch in the skeleton structure
    coordinates = skel.path_coordinates(branch_id)
    
    # Fetch the labels at those coordinates from the labels_out array
    branch_labels = labels_out[coordinates[:, 0], coordinates[:, 1], coordinates[:, 2]]
    
    # Find the unique label(s) associated with this branch
    unique_blob_labels = np.unique(branch_labels)
    
    # Store the unique label(s) in the branch_blob_mapping
    if len(unique_blob_labels) > 1:
        branch_blob_mapping[branch_id] = unique_blob_labels
    else:
        branch_blob_mapping[branch_id] = unique_blob_labels[0]
    
    # Step 3: Map each pixel in this branch to its corresponding blob label(s)
    for i, coord in enumerate(coordinates):
        pixel_blob_mapping[tuple(coord)] = branch_labels[i]


binary_volume_copy = np.copy(binary_volume)
while True:
    # Paso 4: Repetir los pasos 2 y 3 hasta que todos los blobs estén conectados
    binary_volume_copy = connect_blobs_3d(labels_out, pixel_blob_mapping, binary_volume_copy)
    
    # Free up memory by deleting unused variables
    del labels_out, pixel_blob_mapping, branch_blob_mapping
    
    labels_out, N = cc3d.connected_components(binary_volume_copy, return_N=True)
    print(f"Number of blobs: {N}")
    
    # Reinitialize pixel_blob_mapping to reduce memory usage
    # Initialize a dictionary to map each branch ID to its corresponding blob(s)
    branch_blob_mapping = {}
    pixel_blob_mapping = np.zeros_like(labels_out, dtype=int)

    skel = Skeleton(binary_volume_copy)
    branch_data = summarize(skel)

    # Step 2: For each branch, get the coordinates and map them to the corresponding blob label(s)
    for branch_id in branch_data.index:
        # Get the coordinates of the current branch in the skeleton structure
        coordinates = skel.path_coordinates(branch_id)
        
        # Fetch the labels at those coordinates from the labels_out array
        branch_labels = labels_out[coordinates[:, 0], coordinates[:, 1], coordinates[:, 2]]
        
        # Find the unique label(s) associated with this branch
        unique_blob_labels = np.unique(branch_labels)
        
        # Store the unique label(s) in the branch_blob_mapping
        if len(unique_blob_labels) > 1:
            branch_blob_mapping[branch_id] = unique_blob_labels
        else:
            branch_blob_mapping[branch_id] = unique_blob_labels[0]
        
        # Step 3: Map each pixel in this branch to its corresponding blob label(s)
        for i, coord in enumerate(coordinates):
            pixel_blob_mapping[tuple(coord)] = branch_labels[i]
    
    if N == 14:
        print("All blobs are connected!")
        break

tiff.imwrite('C:/Users/nerea/Documents/MasterDTU/SpacialCourse_Fall24/specialCourse_fall24/outputs/connected_blobs_UNET_TOP.tif', binary_volume_copy)
# Out:
# Number of LAbels: 104
# Connecting blobs 63 and 64
# Closest points: [328  73  74] in blob 63, [329  73  76] in blob 64
# Number of blobs: 103
# Connecting blobs 81 and 82
# Closest points: [357 127  45] in blob 81, [360 127  45] in blob 82
# Number of blobs: 102
# Connecting blobs 27 and 28
# Closest points: [262  88 192] in blob 27, [263  86 193] in blob 28
# Number of blobs: 101
# Connecting blobs 41 and 42
# Closest points: [300 167 106] in blob 41, [300 169 103] in blob 42
# Number of blobs: 100
# Connecting blobs 91 and 92
# Closest points: [381 113   6] in blob 91, [384 114   8] in blob 92
# Number of blobs: 99
# Connecting blobs 57 and 60
# Closest points: [324  64  93] in blob 57, [327  65  94] in blob 60
# Number of blobs: 98
# Connecting blobs 80 and 84
# Closest points: [366 123  45] in blob 80, [368 122  44] in blob 84
# Number of blobs: 97
# Connecting blobs 35 and 36
# Closest points: [291 118 141] in blob 35, [293 118 142] in blob 36
# Number of blobs: 96
# Connecting blobs 81 and 85
# Closest points: [367  55  75] in blob 81, [372  55  74] in blob 85
# Number of blobs: 95
# Connecting blobs 89 and 91
# Closest points: [390 111  33] in blob 89, [392 111  34] in blob 91
# Number of blobs: 94
# Connecting blobs 26 and 27
# Closest points: [260  90 190] in blob 26, [262  88 192] in blob 27
# Number of blobs: 93
# Connecting blobs 18 and 21
# Closest points: [237 165 113] in blob 18, [240 163 117] in blob 21
# Number of blobs: 92
# Connecting blobs 24 and 26
# Closest points: [260 180 108] in blob 24, [263 176 105] in blob 26
# Number of blobs: 91
# Connecting blobs 45 and 47
# Closest points: [313 118 114] in blob 45, [315 119 115] in blob 47
# Number of blobs: 90
# Connecting blobs 73 and 75
# Closest points: [360 126  45] in blob 73, [362 126  44] in blob 75
# Number of blobs: 89
# Connecting blobs 77 and 81
# Closest points: [374  97  34] in blob 77, [376  98  33] in blob 81
# Number of blobs: 88
# Connecting blobs 17 and 20
# Closest points: [236 185  79] in blob 17, [239 184  84] in blob 20
# Number of blobs: 87
# Connecting blobs 35 and 36
# Closest points: [299 170 101] in blob 35, [300 169 103] in blob 36
# Number of blobs: 86
# Connecting blobs 61 and 62
# Closest points: [335 138  48] in blob 61, [337 140  48] in blob 62
# Number of blobs: 85
# Connecting blobs 34 and 39
# Closest points: [298  89 133] in blob 34, [305  89 135] in blob 39
# Number of blobs: 84
# Connecting blobs 76 and 77
# Closest points: [378 112   4] in blob 76, [381 113   6] in blob 77
# Number of blobs: 83
# Connecting blobs 33 and 36
# Closest points: [296 108 103] in blob 33, [302 111 108] in blob 36
# Number of blobs: 82
# Connecting blobs 2 and 3
# Closest points: [181 159 191] in blob 2, [184 161 193] in blob 3
# Number of blobs: 81
# Connecting blobs 59 and 62
# Closest points: [339  62 165] in blob 59, [345  62 159] in blob 62
# Number of blobs: 80
# Connecting blobs 45 and 49
# Closest points: [322  88  67] in blob 45, [325  85  72] in blob 49
# Number of blobs: 79
# Connecting blobs 69 and 71
# Closest points: [375  98  33] in blob 69, [375 103  32] in blob 71
# Number of blobs: 78
# Connecting blobs 2 and 3
# Closest points: [186 169 197] in blob 2, [189 171 198] in blob 3
# Number of blobs: 77
# Connecting blobs 16 and 19
# Closest points: [240 162 117] in blob 16, [246 160 119] in blob 19
# Number of blobs: 76
# Connecting blobs 50 and 52
# Closest points: [331  50 141] in blob 50, [334  51 143] in blob 52
# Number of blobs: 75
# Connecting blobs 71 and 73
# Closest points: [388   1  92] in blob 71, [397   6  93] in blob 73
# Number of blobs: 74
# Connecting blobs 67 and 69
# Closest points: [388  37 172] in blob 67, [385  39 176] in blob 69
# Number of blobs: 73
# Connecting blobs 12 and 14
# Closest points: [225 141 157] in blob 12, [227 137 154] in blob 14
# Number of blobs: 72
# Connecting blobs 8 and 10
# Closest points: [209 149 147] in blob 8, [219 155 147] in blob 10
# Number of blobs: 71
# Connecting blobs 52 and 57
# Closest points: [346 144  46] in blob 52, [350 145  48] in blob 57
# Number of blobs: 70
# Connecting blobs 5 and 6
# Closest points: [212 149 199] in blob 5, [211 147 199] in blob 6
# Number of blobs: 69
# Connecting blobs 40 and 44
# Closest points: [327  81  76] in blob 40, [329  73  76] in blob 44
# Number of blobs: 68
# Connecting blobs 58 and 61
# Closest points: [365  90  32] in blob 58, [367  91  32] in blob 61
# Number of blobs: 67
# Connecting blobs 13 and 14
# Closest points: [246 160 120] in blob 13, [243 162 124] in blob 14
# Number of blobs: 66
# Connecting blobs 24 and 29
# Closest points: [295 117 145] in blob 24, [304 108 143] in blob 29
# Number of blobs: 65
# Connecting blobs 37 and 39
# Closest points: [322 182   8] in blob 37, [323 180   9] in blob 39
# Number of blobs: 64
# Connecting blobs 14 and 16
# Closest points: [256 179 105] in blob 14, [259 180 107] in blob 16
# Number of blobs: 63
# Connecting blobs 49 and 51
# Closest points: [347  41 108] in blob 49, [354  43 104] in blob 51
# Number of blobs: 62
# Connecting blobs 16 and 18
# Closest points: [266  86 193] in blob 16, [273  83 192] in blob 18
# Number of blobs: 61
# Connecting blobs 2 and 4
# Closest points: [193 170 188] in blob 2, [194 169 180] in blob 4
# Number of blobs: 60
# Connecting blobs 26 and 34
# Closest points: [314 169  12] in blob 26, [322 171  10] in blob 34
# Number of blobs: 59
# Connecting blobs 51 and 52
# Closest points: [365  42  66] in blob 51, [366  54  75] in blob 52
# Number of blobs: 58
# Connecting blobs 47 and 49
# Closest points: [348 121  51] in blob 47, [357 127  45] in blob 49
# Number of blobs: 57
# Connecting blobs 21 and 27
# Closest points: [304 108 143] in blob 21, [306 109 145] in blob 27
# Number of blobs: 56
# Connecting blobs 44 and 47
# Closest points: [342 119  15] in blob 44, [357 121  21] in blob 47
# Number of blobs: 55
# Connecting blobs 23 and 29
# Closest points: [302 111 108] in blob 23, [308 114 112] in blob 29
# Number of blobs: 54
# Connecting blobs 26 and 30
# Closest points: [318 170  11] in blob 26, [318 168  13] in blob 30
# Number of blobs: 53
# Connecting blobs 6 and 9
# Closest points: [219 155 148] in blob 6, [222 148 161] in blob 9
# Number of blobs: 52
# Connecting blobs 18 and 27
# Closest points: [300 151 149] in blob 18, [307 163 154] in blob 27
# Number of blobs: 51
# Connecting blobs 27 and 30
# Closest points: [335  71 101] in blob 27, [328  66  94] in blob 30
# Number of blobs: 50
# Connecting blobs 33 and 38
# Closest points: [343  59 152] in blob 33, [345  62 158] in blob 38
# Number of blobs: 48
# Connecting blobs 12 and 15
# Closest points: [260 180 108] in blob 12, [267 187 109] in blob 15
# Number of blobs: 47
# Connecting blobs 5 and 9
# Closest points: [235 138 195] in blob 5, [225 131 187] in blob 9
# Number of blobs: 46
# Connecting blobs 13 and 14
# Closest points: [273  83 192] in blob 13, [276  89 194] in blob 14
# Number of blobs: 45
# Connecting blobs 42 and 44
# Closest points: [398   7  92] in blob 42, [398  19  93] in blob 44
# Number of blobs: 44
# Connecting blobs 32 and 33
# Closest points: [343 156  58] in blob 32, [352 148  52] in blob 33
# Number of blobs: 43
# Connecting blobs 24 and 26
# Closest points: [328  66  94] in blob 24, [329  73  76] in blob 26
# Number of blobs: 42
# Connecting blobs 35 and 39
# Closest points: [375 103  31] in blob 35, [386 110  31] in blob 39
# Number of blobs: 41
# Connecting blobs 6 and 8
# Closest points: [219 155 146] in blob 6, [236 163 143] in blob 8
# Number of blobs: 40
# Connecting blobs 17 and 20
# Closest points: [298 175  93] in blob 17, [299 174  96] in blob 20
# Number of blobs: 39
# Connecting blobs 1 and 2
# Closest points: [173 181 198] in blob 1, [186 169 197] in blob 2
# Number of blobs: 38
# Connecting blobs 15 and 23
# Closest points: [312 114 156] in blob 15, [323 105 161] in blob 23
# Number of blobs: 37
# Connecting blobs 19 and 20
# Closest points: [321 192  14] in blob 19, [305 195  18] in blob 20
# Number of blobs: 36
# Connecting blobs 12 and 13
# Closest points: [280 177 132] in blob 12, [281 176 134] in blob 13
# Number of blobs: 35
# Connecting blobs 3 and 4
# Closest points: [205 163 194] in blob 3, [206 164 192] in blob 4
# Number of blobs: 34
# Connecting blobs 25 and 27
# Closest points: [358 121  21] in blob 25, [365 124  43] in blob 27
# Number of blobs: 33
# Connecting blobs 25 and 27
# Closest points: [359 121  24] in blob 25, [370 103  26] in blob 27
# Number of blobs: 32
# Connecting blobs 25 and 29
# Closest points: [386 110  31] in blob 25, [384 114   8] in blob 29
# Number of blobs: 31
# Connecting blobs 6 and 8
# Closest points: [240 183  85] in blob 6, [243 182  92] in blob 8
# Number of blobs: 30
# Connecting blobs 15 and 19
# Closest points: [306  89 135] in blob 15, [330  78 136] in blob 19
# Number of blobs: 29
# Connecting blobs 28 and 29
# Closest points: [397  51  87] in blob 28, [399  48  58] in blob 29
# Number of blobs: 28
# Connecting blobs 25 and 28
# Closest points: [372  55  74] in blob 25, [397  50  80] in blob 28
# Number of blobs: 26
# Connecting blobs 6 and 7
# Closest points: [255 179 105] in blob 6, [249 159 112] in blob 7
# Number of blobs: 25
# Connecting blobs 4 and 5
# Closest points: [219 178 163] in blob 4, [217 178 164] in blob 5
# Number of blobs: 24
# Connecting blobs 9 and 17
# Closest points: [330 185 178] in blob 9, [332 184 180] in blob 17
# Number of blobs: 23
# Connecting blobs 10 and 13
# Closest points: [303 107 140] in blob 10, [304  89 135] in blob 13
# Number of blobs: 22
# Connecting blobs 10 and 12
# Closest points: [303 105 139] in blob 10, [311 116 114] in blob 12
# Number of blobs: 21
# Connecting blobs 3 and 4
# Closest points: [210 189 179] in blob 3, [209 188 177] in blob 4
# Number of blobs: 20
# Connecting blobs 11 and 13
# Closest points: [316 159  27] in blob 11, [318 143  24] in blob 13
# Number of blobs: 19
# Connecting blobs 7 and 8
# Closest points: [307 164 154] in blob 7, [308 168 158] in blob 8
# Number of blobs: 18
# Connecting blobs 11 and 12
# Closest points: [344  65 102] in blob 11, [346  66 101] in blob 12
# Number of blobs: 17
# Connecting blobs 5 and 6
# Closest points: [250 106 160] in blob 5, [260  90 190] in blob 6
# Number of blobs: 16
# Connecting blobs 14 and 16
# Closest points: [361  29 106] in blob 14, [398  29  96] in blob 16
# Number of blobs: 15
# Connecting blobs 4 and 8
# Closest points: [267 187 109] in blob 4, [298 175  94] in blob 8
# Number of blobs: 14
# All blobs are connected!
