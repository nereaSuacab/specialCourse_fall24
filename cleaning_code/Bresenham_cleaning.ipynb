# %%
#Read tif volume
import numpy as np
import tifffile as tiff
import os
import sys
import matplotlib.pyplot as plt

def read_tif_volume(tif_file):
    #Read tif volume
    volume = tiff.imread(tif_file)
    return volume

def write_tif_volume(volume, tif_file):
    tiff.imwrite(tif_file, volume)

# %%
skeleton = read_tif_volume('outputs/output_skeleton_volume.tif')

print(f"Number of pixels in the volume: {np.size(skeleton)}")
print(f"Number of pixels set to True: {np.sum(skeleton==True)}")
print(f"Number of pixels set to False: {np.sum(skeleton == False, dtype=np.int64)}")
# Out:
# Number of pixels in the volume: 2666222100
# Number of pixels set to True: 133044
# Number of pixels set to False: 2666089056

# %%
sk_copy = skeleton.copy()

from skan import Skeleton, summarize

branch_data = summarize(Skeleton(sk_copy))

branch_type_0 =  branch_data[branch_data['branch-type'] == 0]
branch_type_1 =  branch_data[branch_data['branch-type'] == 1]
branch_type_2 =  branch_data[branch_data['branch-type'] == 2]
branch_type_3 =  branch_data[branch_data['branch-type'] == 3]

print(f"Number of branch type 0: {len(branch_type_0)}")
print(f"Number of branch type 1: {len(branch_type_1)}")
print(f"Number of branch type 2: {len(branch_type_2)}")
print(f"Number of branch type 3: {len(branch_type_3)}")
# Out:
# Number of branch type 0: 47
# Number of branch type 1: 4486
# Number of branch type 2: 5268
# Number of branch type 3: 17

# %%
# Iterate over the short branches and set the corresponding pixels to 0 in the binary volume
for _, row in branch_type_3.iterrows():
    src_z, src_y, src_x = int(row['image-coord-src-0']), int(row['image-coord-src-1']), int(row['image-coord-src-2'])
    dst_z, dst_y, dst_x = int(row['image-coord-dst-0']), int(row['image-coord-dst-1']), int(row['image-coord-dst-2'])
    print(f"Source pixel: {src_z}, {src_y}, {src_x}")
    print(f"Destination pixel: {dst_z}, {dst_y}, {dst_x}")

    # Set the source and destination pixels to 0
    sk_copy[src_z, src_y, src_x] = 0
    sk_copy[dst_z, dst_y, dst_x] = 0

print("Branch type 3 removed.")

print(f"Number of pixels in the volume: {np.size(sk_copy)}")
print(f"Number of pixels set to True: {np.sum(sk_copy==True)}")
print(f"Number of pixels set to False: {np.sum(sk_copy == False, dtype=np.int64)}")
# Out:
# Source pixel: 248, 1091, 596
# Destination pixel: 248, 1091, 596
# Source pixel: 334, 990, 1155
# Destination pixel: 334, 990, 1155
# Source pixel: 440, 914, 1185
# Destination pixel: 440, 914, 1185
# Source pixel: 469, 955, 636
# Destination pixel: 469, 955, 636
# Source pixel: 519, 931, 641
# Destination pixel: 519, 931, 641
# Source pixel: 552, 837, 1018
# Destination pixel: 552, 837, 1018
# Source pixel: 580, 1169, 772
# Destination pixel: 580, 1169, 772
# Source pixel: 644, 992, 1146
# Destination pixel: 644, 992, 1146
# Source pixel: 645, 1108, 759
# Destination pixel: 645, 1108, 759
# Source pixel: 670, 764, 1123
# Destination pixel: 670, 764, 1123
# Source pixel: 693, 840, 1034
# Destination pixel: 693, 840, 1034
# Source pixel: 737, 739, 1025
# Destination pixel: 737, 739, 1025
# Source pixel: 746, 699, 521
# Destination pixel: 746, 699, 521
# Source pixel: 786, 857, 898
# Destination pixel: 786, 857, 898
# Source pixel: 796, 374, 601
# Destination pixel: 796, 374, 601
# Source pixel: 796, 939, 760
# Destination pixel: 796, 939, 760
# Source pixel: 823, 450, 689
# Destination pixel: 823, 450, 689
# Branch type 3 removed.
# Number of pixels in the volume: 2666222100
# Number of pixels set to True: 133027
# Number of pixels set to False: 2666089073

# %%
import numpy as np

def bresenham_3d(x1, y1, z1, x2, y2, z2):
    """Bresenham's line algorithm for 3D."""
    points = []
    dx = abs(x2 - x1)
    dy = abs(y2 - y1)
    dz = abs(z2 - z1)
    xs = 1 if x2 > x1 else -1
    ys = 1 if y2 > y1 else -1
    zs = 1 if z2 > z1 else -1

    # Driving axis is X-axis
    if dx >= dy and dx >= dz:
        p1 = 2 * dy - dx
        p2 = 2 * dz - dx
        while x1 != x2:
            points.append((x1, y1, z1))
            x1 += xs
            if p1 >= 0:
                y1 += ys
                p1 -= 2 * dx
            if p2 >= 0:
                z1 += zs
                p2 -= 2 * dx
            p1 += 2 * dy
            p2 += 2 * dz

    # Driving axis is Y-axis
    elif dy >= dx and dy >= dz:
        p1 = 2 * dx - dy
        p2 = 2 * dz - dy
        while y1 != y2:
            points.append((x1, y1, z1))
            y1 += ys
            if p1 >= 0:
                x1 += xs
                p1 -= 2 * dy
            if p2 >= 0:
                z1 += zs
                p2 -= 2 * dy
            p1 += 2 * dx
            p2 += 2 * dz

    # Driving axis is Z-axis
    else:
        p1 = 2 * dy - dz
        p2 = 2 * dx - dz
        while z1 != z2:
            points.append((x1, y1, z1))
            z1 += zs
            if p1 >= 0:
                y1 += ys
                p1 -= 2 * dz
            if p2 >= 0:
                x1 += xs
                p2 -= 2 * dz
            p1 += 2 * dy
            p2 += 2 * dx

    points.append((x2, y2, z2))
    return points

# Iterate over the short branches and set the corresponding pixels to 0 in the binary volume
for _, row in branch_type_0.iterrows():
    src_z, src_y, src_x = int(row['image-coord-src-0']), int(row['image-coord-src-1']), int(row['image-coord-src-2'])
    dst_z, dst_y, dst_x = int(row['image-coord-dst-0']), int(row['image-coord-dst-1']), int(row['image-coord-dst-2'])


    # Get all the pixels between source and destination
    branch_pixels = bresenham_3d(src_x, src_y, src_z, dst_x, dst_y, dst_z)
    print(f"Number of pixels in the branch: {len(branch_pixels)}")



    # Set all the pixels in the branch to 0
    for x, y, z in branch_pixels:
        sk_copy[z, y, x] = 0

print("Branch type 3 removed.")

print(f"Number of pixels in the volume: {np.size(sk_copy)}")
print(f"Number of pixels set to True: {np.sum(sk_copy==True)}")
print(f"Number of pixels set to False: {np.sum(sk_copy == False, dtype=np.int64)}")
# Out:
# Number of pixels in the branch: 15
# Number of pixels in the branch: 10
# Number of pixels in the branch: 2
# Number of pixels in the branch: 2
# Number of pixels in the branch: 3
# Number of pixels in the branch: 3
# Number of pixels in the branch: 2
# Number of pixels in the branch: 3
# Number of pixels in the branch: 3
# Number of pixels in the branch: 4
# Number of pixels in the branch: 14
# Number of pixels in the branch: 5
# Number of pixels in the branch: 4
# Number of pixels in the branch: 3
# Number of pixels in the branch: 3
# Number of pixels in the branch: 3
# Number of pixels in the branch: 2
# Number of pixels in the branch: 2
# Number of pixels in the branch: 2
# Number of pixels in the branch: 2
# Number of pixels in the branch: 2
# Number of pixels in the branch: 2
# Number of pixels in the branch: 8
# Number of pixels in the branch: 23
# Number of pixels in the branch: 2
# Number of pixels in the branch: 11
# Number of pixels in the branch: 22
# Number of pixels in the branch: 9
# Number of pixels in the branch: 2
# Number of pixels in the branch: 22
# Number of pixels in the branch: 2
# Number of pixels in the branch: 29
# Number of pixels in the branch: 17
# Number of pixels in the branch: 24
# Number of pixels in the branch: 14
# Number of pixels in the branch: 5
# Number of pixels in the branch: 9
# Number of pixels in the branch: 71
# Number of pixels in the branch: 9
# Number of pixels in the branch: 13
# Number of pixels in the branch: 12
# Number of pixels in the branch: 20
# Number of pixels in the branch: 10
# Number of pixels in the branch: 13
# Number of pixels in the branch: 12
# Number of pixels in the branch: 12
# Number of pixels in the branch: 10
# Branch type 3 removed.
# Number of pixels in the volume: 2666222100
# Number of pixels set to True: 132860
# Number of pixels set to False: 2666089240

# %%
pixels_to_delete = []
i = 0
# Iterate over the short branches and set the corresponding pixels to 0 in the binary volume
for _, row in branch_type_1.iterrows():
    src_z, src_y, src_x = int(row['image-coord-src-0']), int(row['image-coord-src-1']), int(row['image-coord-src-2'])
    dst_z, dst_y, dst_x = int(row['image-coord-dst-0']), int(row['image-coord-dst-1']), int(row['image-coord-dst-2'])

    # Get all the pixels between source and destination
    branch_pixels = bresenham_3d(src_x, src_y, src_z, dst_x, dst_y, dst_z)
    print(f"Number of pixels in the branch: {len(branch_pixels)}")
    i += 1
    print(f"Branch number: {i}")

    # Save the pixels to delete
    pixels_to_delete.append(branch_pixels)

# Mean value of pixels in a branch
mean_branch_pixels = np.mean([len(branch) for branch in pixels_to_delete])
print(f"Mean number of pixels in a branch: {mean_branch_pixels}")
# Out:
# Number of pixels in the branch: 33
# Branch number: 1
# Number of pixels in the branch: 23
# Branch number: 2
# Number of pixels in the branch: 29
# Branch number: 3
# Number of pixels in the branch: 18
# Branch number: 4
# Number of pixels in the branch: 12
# Branch number: 5
# Number of pixels in the branch: 9
# Branch number: 6
# Number of pixels in the branch: 4
# Branch number: 7
# Number of pixels in the branch: 8
# Branch number: 8
# Number of pixels in the branch: 17
# Branch number: 9
# Number of pixels in the branch: 21
# Branch number: 10
# Number of pixels in the branch: 34
# Branch number: 11
# Number of pixels in the branch: 31
# Branch number: 12
# Number of pixels in the branch: 12
# Branch number: 13
# Number of pixels in the branch: 21
# Branch number: 14
# Number of pixels in the branch: 25
# Branch number: 15
# Number of pixels in the branch: 32
# Branch number: 16
# Number of pixels in the branch: 16
# Branch number: 17
# Number of pixels in the branch: 49
# Branch number: 18
# Number of pixels in the branch: 11
# Branch number: 19
# Number of pixels in the branch: 15
# Branch number: 20
# Number of pixels in the branch: 35
# Branch number: 21
# Number of pixels in the branch: 18
# Branch number: 22
# Number of pixels in the branch: 8
# Branch number: 23
# Number of pixels in the branch: 9
# Branch number: 24
# Number of pixels in the branch: 20
# Branch number: 25
# Number of pixels in the branch: 20
# Branch number: 26
# Number of pixels in the branch: 24
# Branch number: 27
# Number of pixels in the branch: 10
# Branch number: 28
# Number of pixels in the branch: 38
# Branch number: 29
# Number of pixels in the branch: 8
# Branch number: 30
# Number of pixels in the branch: 20
# Branch number: 31
# Number of pixels in the branch: 11
# Branch number: 32
# Number of pixels in the branch: 22
# Branch number: 33
# Number of pixels in the branch: 67
# Branch number: 34
# Number of pixels in the branch: 4
# Branch number: 35
# Number of pixels in the branch: 3
# Branch number: 36
# Number of pixels in the branch: 11
# Branch number: 37
# Number of pixels in the branch: 26
# Branch number: 38
# Number of pixels in the branch: 5
# Branch number: 39
# Number of pixels in the branch: 35
# Branch number: 40
# Number of pixels in the branch: 23
# Branch number: 41
# Number of pixels in the branch: 11
# Branch number: 42
# Number of pixels in the branch: 16
# Branch number: 43
# Number of pixels in the branch: 13
# Branch number: 44
# Number of pixels in the branch: 11
# Branch number: 45
# Number of pixels in the branch: 8
# Branch number: 46
# Number of pixels in the branch: 11
# Branch number: 47
# Number of pixels in the branch: 32
# Branch number: 48
# Number of pixels in the branch: 22
# Branch number: 49
# Number of pixels in the branch: 6
# Branch number: 50
# Number of pixels in the branch: 14
# Branch number: 51
# Number of pixels in the branch: 3
# Branch number: 52
# Number of pixels in the branch: 6
# Branch number: 53
# Number of pixels in the branch: 3
# Branch number: 54
# Number of pixels in the branch: 9
# Branch number: 55
# Number of pixels in the branch: 16
# Branch number: 56
# Number of pixels in the branch: 3
# Branch number: 57
# Number of pixels in the branch: 59
# Branch number: 58
# Number of pixels in the branch: 13
# Branch number: 59
# Number of pixels in the branch: 22
# Branch number: 60
# Number of pixels in the branch: 10
# Branch number: 61
# Number of pixels in the branch: 17
# Branch number: 62
# Number of pixels in the branch: 15
# Branch number: 63
# Number of pixels in the branch: 13
# Branch number: 64
# Number of pixels in the branch: 6
# Branch number: 65
# Number of pixels in the branch: 3
# Branch number: 66
# Number of pixels in the branch: 11
# Branch number: 67
# Number of pixels in the branch: 33
# Branch number: 68
# Number of pixels in the branch: 22
# Branch number: 69
# Number of pixels in the branch: 15
# Branch number: 70
# Number of pixels in the branch: 16
# Branch number: 71
# Number of pixels in the branch: 6
# Branch number: 72
# Number of pixels in the branch: 15
# Branch number: 73
# Number of pixels in the branch: 7
# Branch number: 74
# Number of pixels in the branch: 10
# Branch number: 75
# Number of pixels in the branch: 3
# Branch number: 76
# Number of pixels in the branch: 28
# Branch number: 77
# Number of pixels in the branch: 10
# Branch number: 78
# Number of pixels in the branch: 9
# Branch number: 79
# Number of pixels in the branch: 7
# Branch number: 80
# Number of pixels in the branch: 29
# Branch number: 81
# Number of pixels in the branch: 14
# Branch number: 82
# Number of pixels in the branch: 53
# Branch number: 83
# Number of pixels in the branch: 2
# Branch number: 84
# Number of pixels in the branch: 13
# Branch number: 85
# Number of pixels in the branch: 13
# Branch number: 86
# Number of pixels in the branch: 10
# Branch number: 87
# Number of pixels in the branch: 17
# Branch number: 88
# Number of pixels in the branch: 3
# Branch number: 89
# Number of pixels in the branch: 25
# Branch number: 90
# Number of pixels in the branch: 10
# Branch number: 91
# Number of pixels in the branch: 5
# Branch number: 92
# Number of pixels in the branch: 27
# Branch number: 93
# Number of pixels in the branch: 16
# Branch number: 94
# Number of pixels in the branch: 32
# Branch number: 95
# Number of pixels in the branch: 3
# Branch number: 96
# Number of pixels in the branch: 9
# Branch number: 97
# Number of pixels in the branch: 21
# Branch number: 98
# Number of pixels in the branch: 17
# Branch number: 99
# Number of pixels in the branch: 7
# Branch number: 100
# Number of pixels in the branch: 48
# Branch number: 101
# Number of pixels in the branch: 27
# Branch number: 102
# Number of pixels in the branch: 22
# Branch number: 103
# Number of pixels in the branch: 29
# Branch number: 104
# Number of pixels in the branch: 9
# Branch number: 105
# Number of pixels in the branch: 18
# Branch number: 106
# Number of pixels in the branch: 32
# Branch number: 107
# Number of pixels in the branch: 3
# Branch number: 108
# Number of pixels in the branch: 18
# Branch number: 109
# Number of pixels in the branch: 3
# Branch number: 110
# Number of pixels in the branch: 7
# Branch number: 111
# Number of pixels in the branch: 20
# Branch number: 112
# Number of pixels in the branch: 22
# Branch number: 113
# Number of pixels in the branch: 15
# Branch number: 114
# Number of pixels in the branch: 33
# Branch number: 115
# Number of pixels in the branch: 5
# Branch number: 116
# Number of pixels in the branch: 16
# Branch number: 117
# Number of pixels in the branch: 9
# Branch number: 118
# Number of pixels in the branch: 22
# Branch number: 119
# Number of pixels in the branch: 7
# Branch number: 120
# Number of pixels in the branch: 13
# Branch number: 121
# Number of pixels in the branch: 16
# Branch number: 122
# Number of pixels in the branch: 46
# Branch number: 123
# Number of pixels in the branch: 9
# Branch number: 124
# Number of pixels in the branch: 16
# Branch number: 125
# Number of pixels in the branch: 3
# Branch number: 126
# Number of pixels in the branch: 19
# Branch number: 127
# Number of pixels in the branch: 18
# Branch number: 128
# Number of pixels in the branch: 2
# Branch number: 129
# Number of pixels in the branch: 13
# Branch number: 130
# Number of pixels in the branch: 4
# Branch number: 131
# Number of pixels in the branch: 16
# Branch number: 132
# Number of pixels in the branch: 16
# Branch number: 133
# Number of pixels in the branch: 13
# Branch number: 134
# Number of pixels in the branch: 23
# Branch number: 135
# Number of pixels in the branch: 8
# Branch number: 136
# Number of pixels in the branch: 7
# Branch number: 137
# Number of pixels in the branch: 25
# Branch number: 138
# Number of pixels in the branch: 9
# Branch number: 139
# Number of pixels in the branch: 40
# Branch number: 140
# Number of pixels in the branch: 21
# Branch number: 141
# Number of pixels in the branch: 26
# Branch number: 142
# Number of pixels in the branch: 40
# Branch number: 143
# Number of pixels in the branch: 31
# Branch number: 144
# Number of pixels in the branch: 11
# Branch number: 145
# Number of pixels in the branch: 55
# Branch number: 146
# Number of pixels in the branch: 12
# Branch number: 147
# Number of pixels in the branch: 4
# Branch number: 148
# Number of pixels in the branch: 4
# Branch number: 149
# Number of pixels in the branch: 20
# Branch number: 150
# Number of pixels in the branch: 70
# Branch number: 151
# Number of pixels in the branch: 13
# Branch number: 152
# Number of pixels in the branch: 15
# Branch number: 153
# Number of pixels in the branch: 23
# Branch number: 154
# Number of pixels in the branch: 13
# Branch number: 155
# Number of pixels in the branch: 14
# Branch number: 156
# Number of pixels in the branch: 14
# Branch number: 157
# Number of pixels in the branch: 14
# Branch number: 158
# Number of pixels in the branch: 10
# Branch number: 159
# Number of pixels in the branch: 4
# Branch number: 160
# Number of pixels in the branch: 21
# Branch number: 161
# Number of pixels in the branch: 26
# Branch number: 162
# Number of pixels in the branch: 23
# Branch number: 163
# Number of pixels in the branch: 9
# Branch number: 164
# Number of pixels in the branch: 22
# Branch number: 165
# Number of pixels in the branch: 27
# Branch number: 166
# Number of pixels in the branch: 2
# Branch number: 167
# Number of pixels in the branch: 16
# Branch number: 168
# Number of pixels in the branch: 19
# Branch number: 169
# Number of pixels in the branch: 11
# Branch number: 170
# Number of pixels in the branch: 16
# Branch number: 171
# Number of pixels in the branch: 8
# Branch number: 172
# Number of pixels in the branch: 12
# Branch number: 173
# Number of pixels in the branch: 21
# Branch number: 174
# Number of pixels in the branch: 6
# Branch number: 175
# Number of pixels in the branch: 9
# Branch number: 176
# Number of pixels in the branch: 20
# Branch number: 177
# Number of pixels in the branch: 23
# Branch number: 178
# Number of pixels in the branch: 16
# Branch number: 179
# Number of pixels in the branch: 13
# Branch number: 180
# Number of pixels in the branch: 9
# Branch number: 181
# Number of pixels in the branch: 7
# Branch number: 182
# Number of pixels in the branch: 4
# Branch number: 183
# Number of pixels in the branch: 30
# Branch number: 184
# Number of pixels in the branch: 34
# Branch number: 185
# Number of pixels in the branch: 7
# Branch number: 186
# Number of pixels in the branch: 28
# Branch number: 187
# Number of pixels in the branch: 5
# Branch number: 188
# Number of pixels in the branch: 19
# Branch number: 189
# Number of pixels in the branch: 6
# Branch number: 190
# Number of pixels in the branch: 6
# Branch number: 191
# Number of pixels in the branch: 29
# Branch number: 192
# Number of pixels in the branch: 9
# Branch number: 193
# Number of pixels in the branch: 15
# Branch number: 194
# Number of pixels in the branch: 11
# Branch number: 195
# Number of pixels in the branch: 23
# Branch number: 196
# Number of pixels in the branch: 13
# Branch number: 197
# Number of pixels in the branch: 8
# Branch number: 198
# Number of pixels in the branch: 25
# Branch number: 199
# Number of pixels in the branch: 29
# Branch number: 200
# Number of pixels in the branch: 17
# Branch number: 201
# Number of pixels in the branch: 4
# Branch number: 202
# Number of pixels in the branch: 18
# Branch number: 203
# Number of pixels in the branch: 9
# Branch number: 204
# Number of pixels in the branch: 44
# Branch number: 205
# Number of pixels in the branch: 3
# Branch number: 206
# Number of pixels in the branch: 17
# Branch number: 207
# Number of pixels in the branch: 18
# Branch number: 208
# Number of pixels in the branch: 5
# Branch number: 209
# Number of pixels in the branch: 7
# Branch number: 210
# Number of pixels in the branch: 9
# Branch number: 211
# Number of pixels in the branch: 8
# Branch number: 212
# Number of pixels in the branch: 31
# Branch number: 213
# Number of pixels in the branch: 15
# Branch number: 214
# Number of pixels in the branch: 51
# Branch number: 215
# Number of pixels in the branch: 22
# Branch number: 216
# Number of pixels in the branch: 42
# Branch number: 217
# Number of pixels in the branch: 9
# Branch number: 218
# Number of pixels in the branch: 45
# Branch number: 219
# Number of pixels in the branch: 22
# Branch number: 220
# Number of pixels in the branch: 2
# Branch number: 221
# Number of pixels in the branch: 46
# Branch number: 222
# Number of pixels in the branch: 11
# Branch number: 223
# Number of pixels in the branch: 5
# Branch number: 224
# Number of pixels in the branch: 16
# Branch number: 225
# Number of pixels in the branch: 34
# Branch number: 226
# Number of pixels in the branch: 8
# Branch number: 227
# Number of pixels in the branch: 24
# Branch number: 228
# Number of pixels in the branch: 2
# Branch number: 229
# Number of pixels in the branch: 38
# Branch number: 230
# Number of pixels in the branch: 15
# Branch number: 231
# Number of pixels in the branch: 62
# Branch number: 232
# Number of pixels in the branch: 5
# Branch number: 233
# Number of pixels in the branch: 13
# Branch number: 234
# Number of pixels in the branch: 25
# Branch number: 235
# Number of pixels in the branch: 15
# Branch number: 236
# Number of pixels in the branch: 58
# Branch number: 237
# Number of pixels in the branch: 83
# Branch number: 238
# Number of pixels in the branch: 6
# Branch number: 239
# Number of pixels in the branch: 15
# Branch number: 240
# Number of pixels in the branch: 7
# Branch number: 241
# Number of pixels in the branch: 4
# Branch number: 242
# Number of pixels in the branch: 19
# Branch number: 243
# Number of pixels in the branch: 3
# Branch number: 244
# Number of pixels in the branch: 10
# Branch number: 245
# Number of pixels in the branch: 10
# Branch number: 246
# Number of pixels in the branch: 3
# Branch number: 247
# Number of pixels in the branch: 14
# Branch number: 248
# Number of pixels in the branch: 6
# Branch number: 249
# Number of pixels in the branch: 5
# Branch number: 250
# Number of pixels in the branch: 10
# Branch number: 251
# Number of pixels in the branch: 5
# Branch number: 252
# Number of pixels in the branch: 74
# Branch number: 253
# Number of pixels in the branch: 37
# Branch number: 254
# Number of pixels in the branch: 43
# Branch number: 255
# Number of pixels in the branch: 6
# Branch number: 256
# Number of pixels in the branch: 26
# Branch number: 257
# Number of pixels in the branch: 55
# Branch number: 258
# Number of pixels in the branch: 4
# Branch number: 259
# Number of pixels in the branch: 7
# Branch number: 260
# Number of pixels in the branch: 4
# Branch number: 261
# Number of pixels in the branch: 16
# Branch number: 262
# Number of pixels in the branch: 7
# Branch number: 263
# Number of pixels in the branch: 41
# Branch number: 264
# Number of pixels in the branch: 17
# Branch number: 265
# Number of pixels in the branch: 22
# Branch number: 266
# Number of pixels in the branch: 52
# Branch number: 267
# Number of pixels in the branch: 14
# Branch number: 268
# Number of pixels in the branch: 28
# Branch number: 269
# Number of pixels in the branch: 5
# Branch number: 270
# Number of pixels in the branch: 23
# Branch number: 271
# Number of pixels in the branch: 40
# Branch number: 272
# Number of pixels in the branch: 34
# Branch number: 273
# Number of pixels in the branch: 21
# Branch number: 274
# Number of pixels in the branch: 26
# Branch number: 275
# Number of pixels in the branch: 15
# Branch number: 276
# Number of pixels in the branch: 20
# Branch number: 277
# Number of pixels in the branch: 15
# Branch number: 278
# Number of pixels in the branch: 25
# Branch number: 279
# Number of pixels in the branch: 2
# Branch number: 280
# Number of pixels in the branch: 3
# Branch number: 281
# Number of pixels in the branch: 10
# Branch number: 282
# Number of pixels in the branch: 28
# Branch number: 283
# Number of pixels in the branch: 23
# Branch number: 284
# Number of pixels in the branch: 24
# Branch number: 285
# Number of pixels in the branch: 13
# Branch number: 286
# Number of pixels in the branch: 9
# Branch number: 287
# Number of pixels in the branch: 5
# Branch number: 288
# Number of pixels in the branch: 4
# Branch number: 289
# Number of pixels in the branch: 7
# Branch number: 290
# Number of pixels in the branch: 43
# Branch number: 291
# Number of pixels in the branch: 11
# Branch number: 292
# Number of pixels in the branch: 19
# Branch number: 293
# Number of pixels in the branch: 11
# Branch number: 294
# Number of pixels in the branch: 16
# Branch number: 295
# Number of pixels in the branch: 20
# Branch number: 296
# Number of pixels in the branch: 44
# Branch number: 297
# Number of pixels in the branch: 42
# Branch number: 298
# Number of pixels in the branch: 34
# Branch number: 299
# Number of pixels in the branch: 32
# Branch number: 300
# Number of pixels in the branch: 6
# Branch number: 301
# Number of pixels in the branch: 36
# Branch number: 302
# Number of pixels in the branch: 2
# Branch number: 303
# Number of pixels in the branch: 20
# Branch number: 304
# Number of pixels in the branch: 2
# Branch number: 305
# Number of pixels in the branch: 11
# Branch number: 306
# Number of pixels in the branch: 19
# Branch number: 307
# Number of pixels in the branch: 2
# Branch number: 308
# Number of pixels in the branch: 7
# Branch number: 309
# Number of pixels in the branch: 13
# Branch number: 310
# Number of pixels in the branch: 5
# Branch number: 311
# Number of pixels in the branch: 20
# Branch number: 312
# Number of pixels in the branch: 16
# Branch number: 313
# Number of pixels in the branch: 61
# Branch number: 314
# Number of pixels in the branch: 45
# Branch number: 315
# Number of pixels in the branch: 4
# Branch number: 316
# Number of pixels in the branch: 6
# Branch number: 317
# Number of pixels in the branch: 21
# Branch number: 318
# Number of pixels in the branch: 5
# Branch number: 319
# Number of pixels in the branch: 22
# Branch number: 320
# Number of pixels in the branch: 16
# Branch number: 321
# Number of pixels in the branch: 21
# Branch number: 322
# Number of pixels in the branch: 15
# Branch number: 323
# Number of pixels in the branch: 13
# Branch number: 324
# Number of pixels in the branch: 4
# Branch number: 325
# Number of pixels in the branch: 32
# Branch number: 326
# Number of pixels in the branch: 3
# Branch number: 327
# Number of pixels in the branch: 19
# Branch number: 328
# Number of pixels in the branch: 6
# Branch number: 329
# Number of pixels in the branch: 2
# Branch number: 330
# Number of pixels in the branch: 18
# Branch number: 331
# Number of pixels in the branch: 2
# Branch number: 332
# Number of pixels in the branch: 10
# Branch number: 333
# Number of pixels in the branch: 9
# Branch number: 334
# Number of pixels in the branch: 6
# Branch number: 335
# Number of pixels in the branch: 21
# Branch number: 336
# Number of pixels in the branch: 22
# Branch number: 337
# Number of pixels in the branch: 4
# Branch number: 338
# Number of pixels in the branch: 18
# Branch number: 339
# Number of pixels in the branch: 24
# Branch number: 340
# Number of pixels in the branch: 13
# Branch number: 341
# Number of pixels in the branch: 11
# Branch number: 342
# Number of pixels in the branch: 40
# Branch number: 343
# Number of pixels in the branch: 9
# Branch number: 344
# Number of pixels in the branch: 20
# Branch number: 345
# Number of pixels in the branch: 19
# Branch number: 346
# Number of pixels in the branch: 12
# Branch number: 347
# Number of pixels in the branch: 17
# Branch number: 348
# Number of pixels in the branch: 3
# Branch number: 349
# Number of pixels in the branch: 15
# Branch number: 350
# Number of pixels in the branch: 25
# Branch number: 351
# Number of pixels in the branch: 43
# Branch number: 352
# Number of pixels in the branch: 7
# Branch number: 353
# Number of pixels in the branch: 3
# Branch number: 354
# Number of pixels in the branch: 15
# Branch number: 355
# Number of pixels in the branch: 14
# Branch number: 356
# Number of pixels in the branch: 25
# Branch number: 357
# Number of pixels in the branch: 29
# Branch number: 358
# Number of pixels in the branch: 18
# Branch number: 359
# Number of pixels in the branch: 5
# Branch number: 360
# Number of pixels in the branch: 17
# Branch number: 361
# Number of pixels in the branch: 4
# Branch number: 362
# Number of pixels in the branch: 7
# Branch number: 363
# Number of pixels in the branch: 15
# Branch number: 364
# Number of pixels in the branch: 35
# Branch number: 365
# Number of pixels in the branch: 13
# Branch number: 366
# Number of pixels in the branch: 7
# Branch number: 367
# Number of pixels in the branch: 17
# Branch number: 368
# Number of pixels in the branch: 20
# Branch number: 369
# Number of pixels in the branch: 7
# Branch number: 370
# Number of pixels in the branch: 5
# Branch number: 371
# Number of pixels in the branch: 2
# Branch number: 372
# Number of pixels in the branch: 2
# Branch number: 373
# Number of pixels in the branch: 12
# Branch number: 374
# Number of pixels in the branch: 19
# Branch number: 375
# Number of pixels in the branch: 2
# Branch number: 376
# Number of pixels in the branch: 2
# Branch number: 377
# Number of pixels in the branch: 5
# Branch number: 378
# Number of pixels in the branch: 4
# Branch number: 379
# Number of pixels in the branch: 12
# Branch number: 380
# Number of pixels in the branch: 2
# Branch number: 381
# Number of pixels in the branch: 19
# Branch number: 382
# Number of pixels in the branch: 9
# Branch number: 383
# Number of pixels in the branch: 13
# Branch number: 384
# Number of pixels in the branch: 13
# Branch number: 385
# Number of pixels in the branch: 3
# Branch number: 386
# Number of pixels in the branch: 6
# Branch number: 387
# Number of pixels in the branch: 10
# Branch number: 388
# Number of pixels in the branch: 2
# Branch number: 389
# Number of pixels in the branch: 22
# Branch number: 390
# Number of pixels in the branch: 32
# Branch number: 391
# Number of pixels in the branch: 18
# Branch number: 392
# Number of pixels in the branch: 10
# Branch number: 393
# Number of pixels in the branch: 19
# Branch number: 394
# Number of pixels in the branch: 37
# Branch number: 395
# Number of pixels in the branch: 14
# Branch number: 396
# Number of pixels in the branch: 9
# Branch number: 397
# Number of pixels in the branch: 51
# Branch number: 398
# Number of pixels in the branch: 24
# Branch number: 399
# Number of pixels in the branch: 8
# Branch number: 400
# Number of pixels in the branch: 26
# Branch number: 401
# Number of pixels in the branch: 12
# Branch number: 402
# Number of pixels in the branch: 6
# Branch number: 403
# Number of pixels in the branch: 4
# Branch number: 404
# Number of pixels in the branch: 20
# Branch number: 405
# Number of pixels in the branch: 4
# Branch number: 406
# Number of pixels in the branch: 15
# Branch number: 407
# Number of pixels in the branch: 12
# Branch number: 408
# Number of pixels in the branch: 21
# Branch number: 409
# Number of pixels in the branch: 16
# Branch number: 410
# Number of pixels in the branch: 13
# Branch number: 411
# Number of pixels in the branch: 5
# Branch number: 412
# Number of pixels in the branch: 35
# Branch number: 413
# Number of pixels in the branch: 13
# Branch number: 414
# Number of pixels in the branch: 7
# Branch number: 415
# Number of pixels in the branch: 3
# Branch number: 416
# Number of pixels in the branch: 17
# Branch number: 417
# Number of pixels in the branch: 4
# Branch number: 418
# Number of pixels in the branch: 17
# Branch number: 419
# Number of pixels in the branch: 26
# Branch number: 420
# Number of pixels in the branch: 31
# Branch number: 421
# Number of pixels in the branch: 3
# Branch number: 422
# Number of pixels in the branch: 6
# Branch number: 423
# Number of pixels in the branch: 10
# Branch number: 424
# Number of pixels in the branch: 14
# Branch number: 425
# Number of pixels in the branch: 4
# Branch number: 426
# Number of pixels in the branch: 11
# Branch number: 427
# Number of pixels in the branch: 7
# Branch number: 428
# Number of pixels in the branch: 5
# Branch number: 429
# Number of pixels in the branch: 24
# Branch number: 430
# Number of pixels in the branch: 2
# Branch number: 431
# Number of pixels in the branch: 2
# Branch number: 432
# Number of pixels in the branch: 4
# Branch number: 433
# Number of pixels in the branch: 4
# Branch number: 434
# Number of pixels in the branch: 22
# Branch number: 435
# Number of pixels in the branch: 31
# Branch number: 436
# Number of pixels in the branch: 4
# Branch number: 437
# Number of pixels in the branch: 31
# Branch number: 438
# Number of pixels in the branch: 16
# Branch number: 439
# Number of pixels in the branch: 35
# Branch number: 440
# Number of pixels in the branch: 2
# Branch number: 441
# Number of pixels in the branch: 2
# Branch number: 442
# Number of pixels in the branch: 73
# Branch number: 443
# Number of pixels in the branch: 11
# Branch number: 444
# Number of pixels in the branch: 25
# Branch number: 445
# Number of pixels in the branch: 31
# Branch number: 446
# Number of pixels in the branch: 17
# Branch number: 447
# Number of pixels in the branch: 8
# Branch number: 448
# Number of pixels in the branch: 19
# Branch number: 449
# Number of pixels in the branch: 20
# Branch number: 450
# Number of pixels in the branch: 16
# Branch number: 451
# Number of pixels in the branch: 54
# Branch number: 452
# Number of pixels in the branch: 18
# Branch number: 453
# Number of pixels in the branch: 6
# Branch number: 454
# Number of pixels in the branch: 2
# Branch number: 455
# Number of pixels in the branch: 19
# Branch number: 456
# Number of pixels in the branch: 6
# Branch number: 457
# Number of pixels in the branch: 7
# Branch number: 458
# Number of pixels in the branch: 22
# Branch number: 459
# Number of pixels in the branch: 11
# Branch number: 460
# Number of pixels in the branch: 15
# Branch number: 461
# Number of pixels in the branch: 14
# Branch number: 462
# Number of pixels in the branch: 2
# Branch number: 463
# Number of pixels in the branch: 14
# Branch number: 464
# Number of pixels in the branch: 11
# Branch number: 465
# Number of pixels in the branch: 16
# Branch number: 466
# Number of pixels in the branch: 2
# Branch number: 467
# Number of pixels in the branch: 4
# Branch number: 468
# Number of pixels in the branch: 38
# Branch number: 469
# Number of pixels in the branch: 13
# Branch number: 470
# Number of pixels in the branch: 23
# Branch number: 471
# Number of pixels in the branch: 13
# Branch number: 472
# Number of pixels in the branch: 4
# Branch number: 473
# Number of pixels in the branch: 18
# Branch number: 474
# Number of pixels in the branch: 2
# Branch number: 475
# Number of pixels in the branch: 15
# Branch number: 476
# Number of pixels in the branch: 3
# Branch number: 477
# Number of pixels in the branch: 23
# Branch number: 478
# Number of pixels in the branch: 4
# Branch number: 479
# Number of pixels in the branch: 7
# Branch number: 480
# Number of pixels in the branch: 35
# Branch number: 481
# Number of pixels in the branch: 16
# Branch number: 482
# Number of pixels in the branch: 22
# Branch number: 483
# Number of pixels in the branch: 9
# Branch number: 484
# Number of pixels in the branch: 15
# Branch number: 485
# Number of pixels in the branch: 21
# Branch number: 486
# Number of pixels in the branch: 11
# Branch number: 487
# Number of pixels in the branch: 15
# Branch number: 488
# Number of pixels in the branch: 10
# Branch number: 489
# Number of pixels in the branch: 15
# Branch number: 490
# Number of pixels in the branch: 2
# Branch number: 491
# Number of pixels in the branch: 8
# Branch number: 492
# Number of pixels in the branch: 9
# Branch number: 493
# Number of pixels in the branch: 17
# Branch number: 494
# Number of pixels in the branch: 63
# Branch number: 495
# Number of pixels in the branch: 13
# Branch number: 496
# Number of pixels in the branch: 14
# Branch number: 497
# Number of pixels in the branch: 12
# Branch number: 498
# Number of pixels in the branch: 2
# Branch number: 499
# Number of pixels in the branch: 4
# Branch number: 500
# Number of pixels in the branch: 28
# Branch number: 501
# Number of pixels in the branch: 14
# Branch number: 502
# Number of pixels in the branch: 4
# Branch number: 503
# Number of pixels in the branch: 10
# Branch number: 504
# Number of pixels in the branch: 9
# Branch number: 505
# Number of pixels in the branch: 29
# Branch number: 506
# Number of pixels in the branch: 12
# Branch number: 507
# Number of pixels in the branch: 18
# Branch number: 508
# Number of pixels in the branch: 11
# Branch number: 509
# Number of pixels in the branch: 7
# Branch number: 510
# Number of pixels in the branch: 13
# Branch number: 511
# Number of pixels in the branch: 29
# Branch number: 512
# Number of pixels in the branch: 26
# Branch number: 513
# Number of pixels in the branch: 10
# Branch number: 514
# Number of pixels in the branch: 3
# Branch number: 515
# Number of pixels in the branch: 26
# Branch number: 516
# Number of pixels in the branch: 43
# Branch number: 517
# Number of pixels in the branch: 8
# Branch number: 518
# Number of pixels in the branch: 3
# Branch number: 519
# Number of pixels in the branch: 10
# Branch number: 520
# Number of pixels in the branch: 4
# Branch number: 521
# Number of pixels in the branch: 10
# Branch number: 522
# Number of pixels in the branch: 8
# Branch number: 523
# Number of pixels in the branch: 4
# Branch number: 524
# Number of pixels in the branch: 12
# Branch number: 525
# Number of pixels in the branch: 6
# Branch number: 526
# Number of pixels in the branch: 5
# Branch number: 527
# Number of pixels in the branch: 3
# Branch number: 528
# Number of pixels in the branch: 9
# Branch number: 529
# Number of pixels in the branch: 2
# Branch number: 530
# Number of pixels in the branch: 3
# Branch number: 531
# Number of pixels in the branch: 5
# Branch number: 532
# Number of pixels in the branch: 6
# Branch number: 533
# Number of pixels in the branch: 12
# Branch number: 534
# Number of pixels in the branch: 15
# Branch number: 535
# Number of pixels in the branch: 6
# Branch number: 536
# Number of pixels in the branch: 4
# Branch number: 537
# Number of pixels in the branch: 4
# Branch number: 538
# Number of pixels in the branch: 5
# Branch number: 539
# Number of pixels in the branch: 42
# Branch number: 540
# Number of pixels in the branch: 32
# Branch number: 541
# Number of pixels in the branch: 24
# Branch number: 542
# Number of pixels in the branch: 16
# Branch number: 543
# Number of pixels in the branch: 7
# Branch number: 544
# Number of pixels in the branch: 3
# Branch number: 545
# Number of pixels in the branch: 37
# Branch number: 546
# Number of pixels in the branch: 10
# Branch number: 547
# Number of pixels in the branch: 3
# Branch number: 548
# Number of pixels in the branch: 2
# Branch number: 549
# Number of pixels in the branch: 42
# Branch number: 550
# Number of pixels in the branch: 21
# Branch number: 551
# Number of pixels in the branch: 13
# Branch number: 552
# Number of pixels in the branch: 14
# Branch number: 553
# Number of pixels in the branch: 20
# Branch number: 554
# Number of pixels in the branch: 20
# Branch number: 555
# Number of pixels in the branch: 5
# Branch number: 556
# Number of pixels in the branch: 10
# Branch number: 557
# Number of pixels in the branch: 7
# Branch number: 558
# Number of pixels in the branch: 10
# Branch number: 559
# Number of pixels in the branch: 14
# Branch number: 560
# Number of pixels in the branch: 4
# Branch number: 561
# Number of pixels in the branch: 14
# Branch number: 562
# Number of pixels in the branch: 28
# Branch number: 563
# Number of pixels in the branch: 64
# Branch number: 564
# Number of pixels in the branch: 47
# Branch number: 565
# Number of pixels in the branch: 2
# Branch number: 566
# Number of pixels in the branch: 3
# Branch number: 567
# Number of pixels in the branch: 3
# Branch number: 568
# Number of pixels in the branch: 3
# Branch number: 569
# Number of pixels in the branch: 21
# Branch number: 570
# Number of pixels in the branch: 24
# Branch number: 571
# Number of pixels in the branch: 32
# Branch number: 572
# Number of pixels in the branch: 5
# Branch number: 573
# Number of pixels in the branch: 5
# Branch number: 574
# Number of pixels in the branch: 4
# Branch number: 575
# Number of pixels in the branch: 45
# Branch number: 576
# Number of pixels in the branch: 25
# Branch number: 577
# Number of pixels in the branch: 3
# Branch number: 578
# Number of pixels in the branch: 32
# Branch number: 579
# Number of pixels in the branch: 13
# Branch number: 580
# Number of pixels in the branch: 4
# Branch number: 581
# Number of pixels in the branch: 22
# Branch number: 582
# Number of pixels in the branch: 13
# Branch number: 583
# Number of pixels in the branch: 4
# Branch number: 584
# Number of pixels in the branch: 23
# Branch number: 585
# Number of pixels in the branch: 28
# Branch number: 586
# Number of pixels in the branch: 4
# Branch number: 587
# Number of pixels in the branch: 13
# Branch number: 588
# Number of pixels in the branch: 3
# Branch number: 589
# Number of pixels in the branch: 2
# Branch number: 590
# Number of pixels in the branch: 2
# Branch number: 591
# Number of pixels in the branch: 2
# Branch number: 592
# Number of pixels in the branch: 7
# Branch number: 593
# Number of pixels in the branch: 7
# Branch number: 594
# Number of pixels in the branch: 12
# Branch number: 595
# Number of pixels in the branch: 22
# Branch number: 596
# Number of pixels in the branch: 14
# Branch number: 597
# Number of pixels in the branch: 6
# Branch number: 598
# Number of pixels in the branch: 7
# Branch number: 599
# Number of pixels in the branch: 21
# Branch number: 600
# Number of pixels in the branch: 5
# Branch number: 601
# Number of pixels in the branch: 8
# Branch number: 602
# Number of pixels in the branch: 3
# Branch number: 603
# Number of pixels in the branch: 9
# Branch number: 604
# Number of pixels in the branch: 11
# Branch number: 605
# Number of pixels in the branch: 2
# Branch number: 606
# Number of pixels in the branch: 34
# Branch number: 607
# Number of pixels in the branch: 48
# Branch number: 608
# Number of pixels in the branch: 11
# Branch number: 609
# Number of pixels in the branch: 10
# Branch number: 610
# Number of pixels in the branch: 10
# Branch number: 611
# Number of pixels in the branch: 7
# Branch number: 612
# Number of pixels in the branch: 5
# Branch number: 613
# Number of pixels in the branch: 2
# Branch number: 614
# Number of pixels in the branch: 2
# Branch number: 615
# Number of pixels in the branch: 23
# Branch number: 616
# Number of pixels in the branch: 18
# Branch number: 617
# Number of pixels in the branch: 3
# Branch number: 618
# Number of pixels in the branch: 14
# Branch number: 619
# Number of pixels in the branch: 2
# Branch number: 620
# Number of pixels in the branch: 2
# Branch number: 621
# Number of pixels in the branch: 10
# Branch number: 622
# Number of pixels in the branch: 8
# Branch number: 623
# Number of pixels in the branch: 19
# Branch number: 624
# Number of pixels in the branch: 10
# Branch number: 625
# Number of pixels in the branch: 3
# Branch number: 626
# Number of pixels in the branch: 2
# Branch number: 627
# Number of pixels in the branch: 2
# Branch number: 628
# Number of pixels in the branch: 3
# Branch number: 629
# Number of pixels in the branch: 12
# Branch number: 630
# Number of pixels in the branch: 8
# Branch number: 631
# Number of pixels in the branch: 2
# Branch number: 632
# Number of pixels in the branch: 2
# Branch number: 633
# Number of pixels in the branch: 3
# Branch number: 634
# Number of pixels in the branch: 2
# Branch number: 635
# Number of pixels in the branch: 19
# Branch number: 636
# Number of pixels in the branch: 14
# Branch number: 637
# Number of pixels in the branch: 5
# Branch number: 638
# Number of pixels in the branch: 13
# Branch number: 639
# Number of pixels in the branch: 8
# Branch number: 640
# Number of pixels in the branch: 2
# Branch number: 641
# Number of pixels in the branch: 3
# Branch number: 642
# Number of pixels in the branch: 4
# Branch number: 643
# Number of pixels in the branch: 10
# Branch number: 644
# Number of pixels in the branch: 19
# Branch number: 645
# Number of pixels in the branch: 9
# Branch number: 646
# Number of pixels in the branch: 8
# Branch number: 647
# Number of pixels in the branch: 24
# Branch number: 648
# Number of pixels in the branch: 4
# Branch number: 649
# Number of pixels in the branch: 11
# Branch number: 650
# Number of pixels in the branch: 11
# Branch number: 651
# Number of pixels in the branch: 3
# Branch number: 652
# Number of pixels in the branch: 15
# Branch number: 653
# Number of pixels in the branch: 34
# Branch number: 654
# Number of pixels in the branch: 29
# Branch number: 655
# Number of pixels in the branch: 5
# Branch number: 656
# Number of pixels in the branch: 7
# Branch number: 657
# Number of pixels in the branch: 3
# Branch number: 658
# Number of pixels in the branch: 10
# Branch number: 659
# Number of pixels in the branch: 26
# Branch number: 660
# Number of pixels in the branch: 63
# Branch number: 661
# Number of pixels in the branch: 4
# Branch number: 662
# Number of pixels in the branch: 26
# Branch number: 663
# Number of pixels in the branch: 13
# Branch number: 664
# Number of pixels in the branch: 10
# Branch number: 665
# Number of pixels in the branch: 3
# Branch number: 666
# Number of pixels in the branch: 5
# Branch number: 667
# Number of pixels in the branch: 2
# Branch number: 668
# Number of pixels in the branch: 4
# Branch number: 669
# Number of pixels in the branch: 2
# Branch number: 670
# Number of pixels in the branch: 4
# Branch number: 671
# Number of pixels in the branch: 3
# Branch number: 672
# Number of pixels in the branch: 4
# Branch number: 673
# Number of pixels in the branch: 14
# Branch number: 674
# Number of pixels in the branch: 3
# Branch number: 675
# Number of pixels in the branch: 2
# Branch number: 676
# Number of pixels in the branch: 3
# Branch number: 677
# Number of pixels in the branch: 47
# Branch number: 678
# Number of pixels in the branch: 7
# Branch number: 679
# Number of pixels in the branch: 17
# Branch number: 680
# Number of pixels in the branch: 3
# Branch number: 681
# Number of pixels in the branch: 20
# Branch number: 682
# Number of pixels in the branch: 23
# Branch number: 683
# Number of pixels in the branch: 21
# Branch number: 684
# Number of pixels in the branch: 2
# Branch number: 685
# Number of pixels in the branch: 59
# Branch number: 686
# Number of pixels in the branch: 10
# Branch number: 687
# Number of pixels in the branch: 3
# Branch number: 688
# Number of pixels in the branch: 3
# Branch number: 689
# Number of pixels in the branch: 5
# Branch number: 690
# Number of pixels in the branch: 17
# Branch number: 691
# Number of pixels in the branch: 16
# Branch number: 692
# Number of pixels in the branch: 12
# Branch number: 693
# Number of pixels in the branch: 28
# Branch number: 694
# Number of pixels in the branch: 3
# Branch number: 695
# Number of pixels in the branch: 2
# Branch number: 696
# Number of pixels in the branch: 3
# Branch number: 697
# Number of pixels in the branch: 18
# Branch number: 698
# Number of pixels in the branch: 32
# Branch number: 699
# Number of pixels in the branch: 7
# Branch number: 700
# Number of pixels in the branch: 2
# Branch number: 701
# Number of pixels in the branch: 18
# Branch number: 702
# Number of pixels in the branch: 14
# Branch number: 703
# Number of pixels in the branch: 2
# Branch number: 704
# Number of pixels in the branch: 6
# Branch number: 705
# Number of pixels in the branch: 4
# Branch number: 706
# Number of pixels in the branch: 49
# Branch number: 707
# Number of pixels in the branch: 29
# Branch number: 708
# Number of pixels in the branch: 2
# Branch number: 709
# Number of pixels in the branch: 4
# Branch number: 710
# Number of pixels in the branch: 23
# Branch number: 711
# Number of pixels in the branch: 4
# Branch number: 712
# Number of pixels in the branch: 37
# Branch number: 713
# Number of pixels in the branch: 3
# Branch number: 714
# Number of pixels in the branch: 5
# Branch number: 715
# Number of pixels in the branch: 13
# Branch number: 716
# Number of pixels in the branch: 13
# Branch number: 717
# Number of pixels in the branch: 8
# Branch number: 718
# Number of pixels in the branch: 17
# Branch number: 719
# Number of pixels in the branch: 22
# Branch number: 720
# Number of pixels in the branch: 31
# Branch number: 721
# Number of pixels in the branch: 19
# Branch number: 722
# Number of pixels in the branch: 3
# Branch number: 723
# Number of pixels in the branch: 13
# Branch number: 724
# Number of pixels in the branch: 12
# Branch number: 725
# Number of pixels in the branch: 9
# Branch number: 726
# Number of pixels in the branch: 10
# Branch number: 727
# Number of pixels in the branch: 3
# Branch number: 728
# Number of pixels in the branch: 8
# Branch number: 729
# Number of pixels in the branch: 7
# Branch number: 730
# Number of pixels in the branch: 25
# Branch number: 731
# Number of pixels in the branch: 31
# Branch number: 732
# Number of pixels in the branch: 9
# Branch number: 733
# Number of pixels in the branch: 4
# Branch number: 734
# Number of pixels in the branch: 2
# Branch number: 735
# Number of pixels in the branch: 7
# Branch number: 736
# Number of pixels in the branch: 11
# Branch number: 737
# Number of pixels in the branch: 13
# Branch number: 738
# Number of pixels in the branch: 17
# Branch number: 739
# Number of pixels in the branch: 40
# Branch number: 740
# Number of pixels in the branch: 20
# Branch number: 741
# Number of pixels in the branch: 2
# Branch number: 742
# Number of pixels in the branch: 33
# Branch number: 743
# Number of pixels in the branch: 21
# Branch number: 744
# Number of pixels in the branch: 11
# Branch number: 745
# Number of pixels in the branch: 12
# Branch number: 746
# Number of pixels in the branch: 2
# Branch number: 747
# Number of pixels in the branch: 42
# Branch number: 748
# Number of pixels in the branch: 24
# Branch number: 749
# Number of pixels in the branch: 3
# Branch number: 750
# Number of pixels in the branch: 2
# Branch number: 751
# Number of pixels in the branch: 15
# Branch number: 752
# Number of pixels in the branch: 40
# Branch number: 753
# Number of pixels in the branch: 9
# Branch number: 754
# Number of pixels in the branch: 10
# Branch number: 755
# Number of pixels in the branch: 2
# Branch number: 756
# Number of pixels in the branch: 3
# Branch number: 757
# Number of pixels in the branch: 5
# Branch number: 758
# Number of pixels in the branch: 9
# Branch number: 759
# Number of pixels in the branch: 17
# Branch number: 760
# Number of pixels in the branch: 11
# Branch number: 761
# Number of pixels in the branch: 2
# Branch number: 762
# Number of pixels in the branch: 2
# Branch number: 763
# Number of pixels in the branch: 29
# Branch number: 764
# Number of pixels in the branch: 29
# Branch number: 765
# Number of pixels in the branch: 20
# Branch number: 766
# Number of pixels in the branch: 16
# Branch number: 767
# Number of pixels in the branch: 16
# Branch number: 768
# Number of pixels in the branch: 6
# Branch number: 769
# Number of pixels in the branch: 12
# Branch number: 770
# Number of pixels in the branch: 2
# Branch number: 771
# Number of pixels in the branch: 2
# Branch number: 772
# Number of pixels in the branch: 4
# Branch number: 773
# Number of pixels in the branch: 4
# Branch number: 774
# Number of pixels in the branch: 5
# Branch number: 775
# Number of pixels in the branch: 3
# Branch number: 776
# Number of pixels in the branch: 2
# Branch number: 777
# Number of pixels in the branch: 2
# Branch number: 778
# Number of pixels in the branch: 2
# Branch number: 779
# Number of pixels in the branch: 27
# Branch number: 780
# Number of pixels in the branch: 14
# Branch number: 781
# Number of pixels in the branch: 2
# Branch number: 782
# Number of pixels in the branch: 6
# Branch number: 783
# Number of pixels in the branch: 18
# Branch number: 784
# Number of pixels in the branch: 14
# Branch number: 785
# Number of pixels in the branch: 2
# Branch number: 786
# Number of pixels in the branch: 2
# Branch number: 787
# Number of pixels in the branch: 2
# Branch number: 788
# Number of pixels in the branch: 9
# Branch number: 789
# Number of pixels in the branch: 3
# Branch number: 790
# Number of pixels in the branch: 16
# Branch number: 791
# Number of pixels in the branch: 7
# Branch number: 792
# Number of pixels in the branch: 11
# Branch number: 793
# Number of pixels in the branch: 2
# Branch number: 794
# Number of pixels in the branch: 4
# Branch number: 795
# Number of pixels in the branch: 8
# Branch number: 796
# Number of pixels in the branch: 34
# Branch number: 797
# Number of pixels in the branch: 18
# Branch number: 798
# Number of pixels in the branch: 3
# Branch number: 799
# Number of pixels in the branch: 2
# Branch number: 800
# Number of pixels in the branch: 15
# Branch number: 801
# Number of pixels in the branch: 4
# Branch number: 802
# Number of pixels in the branch: 3
# Branch number: 803
# Number of pixels in the branch: 3
# Branch number: 804
# Number of pixels in the branch: 2
# Branch number: 805
# Number of pixels in the branch: 27
# Branch number: 806
# Number of pixels in the branch: 2
# Branch number: 807
# Number of pixels in the branch: 2
# Branch number: 808
# Number of pixels in the branch: 2
# Branch number: 809
# Number of pixels in the branch: 21
# Branch number: 810
# Number of pixels in the branch: 12
# Branch number: 811
# Number of pixels in the branch: 40
# Branch number: 812
# Number of pixels in the branch: 3
# Branch number: 813
# Number of pixels in the branch: 6
# Branch number: 814
# Number of pixels in the branch: 4
# Branch number: 815
# Number of pixels in the branch: 4
# Branch number: 816
# Number of pixels in the branch: 2
# Branch number: 817
# Number of pixels in the branch: 2
# Branch number: 818
# Number of pixels in the branch: 2
# Branch number: 819
# Number of pixels in the branch: 3
# Branch number: 820
# Number of pixels in the branch: 2
# Branch number: 821
# Number of pixels in the branch: 3
# Branch number: 822
# Number of pixels in the branch: 2
# Branch number: 823
# Number of pixels in the branch: 2
# Branch number: 824
# Number of pixels in the branch: 6
# Branch number: 825
# Number of pixels in the branch: 3
# Branch number: 826
# Number of pixels in the branch: 2
# Branch number: 827
# Number of pixels in the branch: 2
# Branch number: 828
# Number of pixels in the branch: 3
# Branch number: 829
# Number of pixels in the branch: 2
# Branch number: 830
# Number of pixels in the branch: 2
# Branch number: 831
# Number of pixels in the branch: 2
# Branch number: 832
# Number of pixels in the branch: 2
# Branch number: 833
# Number of pixels in the branch: 2
# Branch number: 834
# Number of pixels in the branch: 21
# Branch number: 835
# Number of pixels in the branch: 52
# Branch number: 836
# Number of pixels in the branch: 7
# Branch number: 837
# Number of pixels in the branch: 52
# Branch number: 838
# Number of pixels in the branch: 6
# Branch number: 839
# Number of pixels in the branch: 6
# Branch number: 840
# Number of pixels in the branch: 2
# Branch number: 841
# Number of pixels in the branch: 2
# Branch number: 842
# Number of pixels in the branch: 2
# Branch number: 843
# Number of pixels in the branch: 5
# Branch number: 844
# Number of pixels in the branch: 24
# Branch number: 845
# Number of pixels in the branch: 3
# Branch number: 846
# Number of pixels in the branch: 3
# Branch number: 847
# Number of pixels in the branch: 3
# Branch number: 848
# Number of pixels in the branch: 3
# Branch number: 849
# Number of pixels in the branch: 2
# Branch number: 850
# Number of pixels in the branch: 2
# Branch number: 851
# Number of pixels in the branch: 18
# Branch number: 852
# Number of pixels in the branch: 4
# Branch number: 853
# Number of pixels in the branch: 4
# Branch number: 854
# Number of pixels in the branch: 3
# Branch number: 855
# Number of pixels in the branch: 4
# Branch number: 856
# Number of pixels in the branch: 31
# Branch number: 857
# Number of pixels in the branch: 50
# Branch number: 858
# Number of pixels in the branch: 9
# Branch number: 859
# Number of pixels in the branch: 31
# Branch number: 860
# Number of pixels in the branch: 2
# Branch number: 861
# Number of pixels in the branch: 3
# Branch number: 862
# Number of pixels in the branch: 3
# Branch number: 863
# Number of pixels in the branch: 2
# Branch number: 864
# Number of pixels in the branch: 3
# Branch number: 865
# Number of pixels in the branch: 5
# Branch number: 866
# Number of pixels in the branch: 8
# Branch number: 867
# Number of pixels in the branch: 3
# Branch number: 868
# Number of pixels in the branch: 2
# Branch number: 869
# Number of pixels in the branch: 2
# Branch number: 870
# Number of pixels in the branch: 2
# Branch number: 871
# Number of pixels in the branch: 3
# Branch number: 872
# Number of pixels in the branch: 2
# Branch number: 873
# Number of pixels in the branch: 2
# Branch number: 874
# Number of pixels in the branch: 24
# Branch number: 875
# Number of pixels in the branch: 2
# Branch number: 876
# Number of pixels in the branch: 2
# Branch number: 877
# Number of pixels in the branch: 2
# Branch number: 878
# Number of pixels in the branch: 3
# Branch number: 879
# Number of pixels in the branch: 2
# Branch number: 880
# Number of pixels in the branch: 4
# Branch number: 881
# Number of pixels in the branch: 2
# Branch number: 882
# Number of pixels in the branch: 2
# Branch number: 883
# Number of pixels in the branch: 2
# Branch number: 884
# Number of pixels in the branch: 3
# Branch number: 885
# Number of pixels in the branch: 2
# Branch number: 886
# Number of pixels in the branch: 3
# Branch number: 887
# Number of pixels in the branch: 4
# Branch number: 888
# Number of pixels in the branch: 28
# Branch number: 889
# Number of pixels in the branch: 16
# Branch number: 890
# Number of pixels in the branch: 10
# Branch number: 891
# Number of pixels in the branch: 4
# Branch number: 892
# Number of pixels in the branch: 2
# Branch number: 893
# Number of pixels in the branch: 2
# Branch number: 894
# Number of pixels in the branch: 11
# Branch number: 895
# Number of pixels in the branch: 49
# Branch number: 896
# Number of pixels in the branch: 5
# Branch number: 897
# Number of pixels in the branch: 11
# Branch number: 898
# ...
# Branch number: 4194
# Number of pixels in the branch: 2
# Branch number: 4195
# Number of pixels in the branch: 24
# Branch number: 4196
# Number of pixels in the branch: 12
# Branch number: 4197
# Number of pixels in the branch: 44
# Branch number: 4198
# Number of pixels in the branch: 2
# Branch number: 4199
# Number of pixels in the branch: 5
# Branch number: 4200
# Number of pixels in the branch: 25
# Branch number: 4201
# Number of pixels in the branch: 14
# Branch number: 4202
# Number of pixels in the branch: 11
# Branch number: 4203
# Number of pixels in the branch: 14
# Branch number: 4204
# Number of pixels in the branch: 7
# Branch number: 4205
# Number of pixels in the branch: 3
# Branch number: 4206
# Number of pixels in the branch: 7
# Branch number: 4207
# Number of pixels in the branch: 17
# Branch number: 4208
# Number of pixels in the branch: 21
# Branch number: 4209
# Number of pixels in the branch: 29
# Branch number: 4210
# Number of pixels in the branch: 34
# Branch number: 4211
# Number of pixels in the branch: 2
# Branch number: 4212
# Number of pixels in the branch: 2
# Branch number: 4213
# Number of pixels in the branch: 2
# Branch number: 4214
# Number of pixels in the branch: 36
# Branch number: 4215
# Number of pixels in the branch: 17
# Branch number: 4216
# Number of pixels in the branch: 39
# Branch number: 4217
# Number of pixels in the branch: 8
# Branch number: 4218
# Number of pixels in the branch: 2
# Branch number: 4219
# Number of pixels in the branch: 9
# Branch number: 4220
# Number of pixels in the branch: 4
# Branch number: 4221
# Number of pixels in the branch: 16
# Branch number: 4222
# Number of pixels in the branch: 5
# Branch number: 4223
# Number of pixels in the branch: 3
# Branch number: 4224
# Number of pixels in the branch: 15
# Branch number: 4225
# Number of pixels in the branch: 14
# Branch number: 4226
# Number of pixels in the branch: 23
# Branch number: 4227
# Number of pixels in the branch: 15
# Branch number: 4228
# Number of pixels in the branch: 3
# Branch number: 4229
# Number of pixels in the branch: 17
# Branch number: 4230
# Number of pixels in the branch: 13
# Branch number: 4231
# Number of pixels in the branch: 9
# Branch number: 4232
# Number of pixels in the branch: 12
# Branch number: 4233
# Number of pixels in the branch: 14
# Branch number: 4234
# Number of pixels in the branch: 24
# Branch number: 4235
# Number of pixels in the branch: 10
# Branch number: 4236
# Number of pixels in the branch: 2
# Branch number: 4237
# Number of pixels in the branch: 4
# Branch number: 4238
# Number of pixels in the branch: 6
# Branch number: 4239
# Number of pixels in the branch: 9
# Branch number: 4240
# Number of pixels in the branch: 2
# Branch number: 4241
# Number of pixels in the branch: 2
# Branch number: 4242
# Number of pixels in the branch: 2
# Branch number: 4243
# Number of pixels in the branch: 4
# Branch number: 4244
# Number of pixels in the branch: 2
# Branch number: 4245
# Number of pixels in the branch: 3
# Branch number: 4246
# Number of pixels in the branch: 2
# Branch number: 4247
# Number of pixels in the branch: 3
# Branch number: 4248
# Number of pixels in the branch: 2
# Branch number: 4249
# Number of pixels in the branch: 2
# Branch number: 4250
# Number of pixels in the branch: 2
# Branch number: 4251
# Number of pixels in the branch: 2
# Branch number: 4252
# Number of pixels in the branch: 2
# Branch number: 4253
# Number of pixels in the branch: 2
# Branch number: 4254
# Number of pixels in the branch: 3
# Branch number: 4255
# Number of pixels in the branch: 5
# Branch number: 4256
# Number of pixels in the branch: 28
# Branch number: 4257
# Number of pixels in the branch: 5
# Branch number: 4258
# Number of pixels in the branch: 33
# Branch number: 4259
# Number of pixels in the branch: 27
# Branch number: 4260
# Number of pixels in the branch: 8
# Branch number: 4261
# Number of pixels in the branch: 13
# Branch number: 4262
# Number of pixels in the branch: 8
# Branch number: 4263
# Number of pixels in the branch: 21
# Branch number: 4264
# Number of pixels in the branch: 15
# Branch number: 4265
# Number of pixels in the branch: 4
# Branch number: 4266
# Number of pixels in the branch: 2
# Branch number: 4267
# Number of pixels in the branch: 5
# Branch number: 4268
# Number of pixels in the branch: 3
# Branch number: 4269
# Number of pixels in the branch: 16
# Branch number: 4270
# Number of pixels in the branch: 14
# Branch number: 4271
# Number of pixels in the branch: 31
# Branch number: 4272
# Number of pixels in the branch: 10
# Branch number: 4273
# Number of pixels in the branch: 16
# Branch number: 4274
# Number of pixels in the branch: 29
# Branch number: 4275
# Number of pixels in the branch: 22
# Branch number: 4276
# Number of pixels in the branch: 15
# Branch number: 4277
# Number of pixels in the branch: 8
# Branch number: 4278
# Number of pixels in the branch: 7
# Branch number: 4279
# Number of pixels in the branch: 3
# Branch number: 4280
# Number of pixels in the branch: 17
# Branch number: 4281
# Number of pixels in the branch: 22
# Branch number: 4282
# Number of pixels in the branch: 4
# Branch number: 4283
# Number of pixels in the branch: 11
# Branch number: 4284
# Number of pixels in the branch: 2
# Branch number: 4285
# Number of pixels in the branch: 17
# Branch number: 4286
# Number of pixels in the branch: 8
# Branch number: 4287
# Number of pixels in the branch: 3
# Branch number: 4288
# Number of pixels in the branch: 7
# Branch number: 4289
# Number of pixels in the branch: 31
# Branch number: 4290
# Number of pixels in the branch: 43
# Branch number: 4291
# Number of pixels in the branch: 8
# Branch number: 4292
# Number of pixels in the branch: 13
# Branch number: 4293
# Number of pixels in the branch: 3
# Branch number: 4294
# Number of pixels in the branch: 47
# Branch number: 4295
# Number of pixels in the branch: 2
# Branch number: 4296
# Number of pixels in the branch: 2
# Branch number: 4297
# Number of pixels in the branch: 10
# Branch number: 4298
# Number of pixels in the branch: 25
# Branch number: 4299
# Number of pixels in the branch: 5
# Branch number: 4300
# Number of pixels in the branch: 38
# Branch number: 4301
# Number of pixels in the branch: 10
# Branch number: 4302
# Number of pixels in the branch: 11
# Branch number: 4303
# Number of pixels in the branch: 25
# Branch number: 4304
# Number of pixels in the branch: 14
# Branch number: 4305
# Number of pixels in the branch: 6
# Branch number: 4306
# Number of pixels in the branch: 60
# Branch number: 4307
# Number of pixels in the branch: 35
# Branch number: 4308
# Number of pixels in the branch: 20
# Branch number: 4309
# Number of pixels in the branch: 23
# Branch number: 4310
# Number of pixels in the branch: 3
# Branch number: 4311
# Number of pixels in the branch: 13
# Branch number: 4312
# Number of pixels in the branch: 6
# Branch number: 4313
# Number of pixels in the branch: 33
# Branch number: 4314
# Number of pixels in the branch: 9
# Branch number: 4315
# Number of pixels in the branch: 15
# Branch number: 4316
# Number of pixels in the branch: 13
# Branch number: 4317
# Number of pixels in the branch: 22
# Branch number: 4318
# Number of pixels in the branch: 17
# Branch number: 4319
# Number of pixels in the branch: 33
# Branch number: 4320
# Number of pixels in the branch: 13
# Branch number: 4321
# Number of pixels in the branch: 41
# Branch number: 4322
# Number of pixels in the branch: 18
# Branch number: 4323
# Number of pixels in the branch: 4
# Branch number: 4324
# Number of pixels in the branch: 28
# Branch number: 4325
# Number of pixels in the branch: 12
# Branch number: 4326
# Number of pixels in the branch: 20
# Branch number: 4327
# Number of pixels in the branch: 24
# Branch number: 4328
# Number of pixels in the branch: 23
# Branch number: 4329
# Number of pixels in the branch: 4
# Branch number: 4330
# Number of pixels in the branch: 2
# Branch number: 4331
# Number of pixels in the branch: 2
# Branch number: 4332
# Number of pixels in the branch: 10
# Branch number: 4333
# Number of pixels in the branch: 2
# Branch number: 4334
# Number of pixels in the branch: 2
# Branch number: 4335
# Number of pixels in the branch: 2
# Branch number: 4336
# Number of pixels in the branch: 2
# Branch number: 4337
# Number of pixels in the branch: 19
# Branch number: 4338
# Number of pixels in the branch: 3
# Branch number: 4339
# Number of pixels in the branch: 18
# Branch number: 4340
# Number of pixels in the branch: 9
# Branch number: 4341
# Number of pixels in the branch: 7
# Branch number: 4342
# Number of pixels in the branch: 2
# Branch number: 4343
# Number of pixels in the branch: 26
# Branch number: 4344
# Number of pixels in the branch: 2
# Branch number: 4345
# Number of pixels in the branch: 15
# Branch number: 4346
# Number of pixels in the branch: 8
# Branch number: 4347
# Number of pixels in the branch: 2
# Branch number: 4348
# Number of pixels in the branch: 2
# Branch number: 4349
# Number of pixels in the branch: 3
# Branch number: 4350
# Number of pixels in the branch: 13
# Branch number: 4351
# Number of pixels in the branch: 16
# Branch number: 4352
# Number of pixels in the branch: 27
# Branch number: 4353
# Number of pixels in the branch: 22
# Branch number: 4354
# Number of pixels in the branch: 14
# Branch number: 4355
# Number of pixels in the branch: 5
# Branch number: 4356
# Number of pixels in the branch: 13
# Branch number: 4357
# Number of pixels in the branch: 5
# Branch number: 4358
# Number of pixels in the branch: 4
# Branch number: 4359
# Number of pixels in the branch: 10
# Branch number: 4360
# Number of pixels in the branch: 13
# Branch number: 4361
# Number of pixels in the branch: 4
# Branch number: 4362
# Number of pixels in the branch: 23
# Branch number: 4363
# Number of pixels in the branch: 19
# Branch number: 4364
# Number of pixels in the branch: 16
# Branch number: 4365
# Number of pixels in the branch: 16
# Branch number: 4366
# Number of pixels in the branch: 11
# Branch number: 4367
# Number of pixels in the branch: 2
# Branch number: 4368
# Number of pixels in the branch: 47
# Branch number: 4369
# Number of pixels in the branch: 16
# Branch number: 4370
# Number of pixels in the branch: 7
# Branch number: 4371
# Number of pixels in the branch: 3
# Branch number: 4372
# Number of pixels in the branch: 22
# Branch number: 4373
# Number of pixels in the branch: 6
# Branch number: 4374
# Number of pixels in the branch: 2
# Branch number: 4375
# Number of pixels in the branch: 9
# Branch number: 4376
# Number of pixels in the branch: 4
# Branch number: 4377
# Number of pixels in the branch: 6
# Branch number: 4378
# Number of pixels in the branch: 40
# Branch number: 4379
# Number of pixels in the branch: 21
# Branch number: 4380
# Number of pixels in the branch: 4
# Branch number: 4381
# Number of pixels in the branch: 7
# Branch number: 4382
# Number of pixels in the branch: 5
# Branch number: 4383
# Number of pixels in the branch: 20
# Branch number: 4384
# Number of pixels in the branch: 28
# Branch number: 4385
# Number of pixels in the branch: 16
# Branch number: 4386
# Number of pixels in the branch: 16
# Branch number: 4387
# Number of pixels in the branch: 13
# Branch number: 4388
# Number of pixels in the branch: 12
# Branch number: 4389
# Number of pixels in the branch: 22
# Branch number: 4390
# Number of pixels in the branch: 20
# Branch number: 4391
# Number of pixels in the branch: 5
# Branch number: 4392
# Number of pixels in the branch: 7
# Branch number: 4393
# Number of pixels in the branch: 5
# Branch number: 4394
# Number of pixels in the branch: 8
# Branch number: 4395
# Number of pixels in the branch: 11
# Branch number: 4396
# Number of pixels in the branch: 23
# Branch number: 4397
# Number of pixels in the branch: 2
# Branch number: 4398
# Number of pixels in the branch: 2
# Branch number: 4399
# Number of pixels in the branch: 6
# Branch number: 4400
# Number of pixels in the branch: 6
# Branch number: 4401
# Number of pixels in the branch: 12
# Branch number: 4402
# Number of pixels in the branch: 24
# Branch number: 4403
# Number of pixels in the branch: 15
# Branch number: 4404
# Number of pixels in the branch: 8
# Branch number: 4405
# Number of pixels in the branch: 5
# Branch number: 4406
# Number of pixels in the branch: 3
# Branch number: 4407
# Number of pixels in the branch: 23
# Branch number: 4408
# Number of pixels in the branch: 2
# Branch number: 4409
# Number of pixels in the branch: 23
# Branch number: 4410
# Number of pixels in the branch: 5
# Branch number: 4411
# Number of pixels in the branch: 15
# Branch number: 4412
# Number of pixels in the branch: 15
# Branch number: 4413
# Number of pixels in the branch: 17
# Branch number: 4414
# Number of pixels in the branch: 20
# Branch number: 4415
# Number of pixels in the branch: 9
# Branch number: 4416
# Number of pixels in the branch: 21
# Branch number: 4417
# Number of pixels in the branch: 2
# Branch number: 4418
# Number of pixels in the branch: 11
# Branch number: 4419
# Number of pixels in the branch: 11
# Branch number: 4420
# Number of pixels in the branch: 8
# Branch number: 4421
# Number of pixels in the branch: 5
# Branch number: 4422
# Number of pixels in the branch: 16
# Branch number: 4423
# Number of pixels in the branch: 7
# Branch number: 4424
# Number of pixels in the branch: 20
# Branch number: 4425
# Number of pixels in the branch: 18
# Branch number: 4426
# Number of pixels in the branch: 6
# Branch number: 4427
# Number of pixels in the branch: 22
# Branch number: 4428
# Number of pixels in the branch: 6
# Branch number: 4429
# Number of pixels in the branch: 2
# Branch number: 4430
# Number of pixels in the branch: 12
# Branch number: 4431
# Number of pixels in the branch: 3
# Branch number: 4432
# Number of pixels in the branch: 4
# Branch number: 4433
# Number of pixels in the branch: 14
# Branch number: 4434
# Number of pixels in the branch: 8
# Branch number: 4435
# Number of pixels in the branch: 7
# Branch number: 4436
# Number of pixels in the branch: 5
# Branch number: 4437
# Number of pixels in the branch: 15
# Branch number: 4438
# Number of pixels in the branch: 9
# Branch number: 4439
# Number of pixels in the branch: 4
# Branch number: 4440
# Number of pixels in the branch: 3
# Branch number: 4441
# Number of pixels in the branch: 14
# Branch number: 4442
# Number of pixels in the branch: 15
# Branch number: 4443
# Number of pixels in the branch: 11
# Branch number: 4444
# Number of pixels in the branch: 2
# Branch number: 4445
# Number of pixels in the branch: 3
# Branch number: 4446
# Number of pixels in the branch: 5
# Branch number: 4447
# Number of pixels in the branch: 2
# Branch number: 4448
# Number of pixels in the branch: 14
# Branch number: 4449
# Number of pixels in the branch: 4
# Branch number: 4450
# Number of pixels in the branch: 51
# Branch number: 4451
# Number of pixels in the branch: 11
# Branch number: 4452
# Number of pixels in the branch: 30
# Branch number: 4453
# Number of pixels in the branch: 16
# Branch number: 4454
# Number of pixels in the branch: 14
# Branch number: 4455
# Number of pixels in the branch: 18
# Branch number: 4456
# Number of pixels in the branch: 3
# Branch number: 4457
# Number of pixels in the branch: 31
# Branch number: 4458
# Number of pixels in the branch: 15
# Branch number: 4459
# Number of pixels in the branch: 25
# Branch number: 4460
# Number of pixels in the branch: 5
# Branch number: 4461
# Number of pixels in the branch: 15
# Branch number: 4462
# Number of pixels in the branch: 30
# Branch number: 4463
# Number of pixels in the branch: 15
# Branch number: 4464
# Number of pixels in the branch: 25
# Branch number: 4465
# Number of pixels in the branch: 9
# Branch number: 4466
# Number of pixels in the branch: 3
# Branch number: 4467
# Number of pixels in the branch: 9
# Branch number: 4468
# Number of pixels in the branch: 10
# Branch number: 4469
# Number of pixels in the branch: 33
# Branch number: 4470
# Number of pixels in the branch: 18
# Branch number: 4471
# Number of pixels in the branch: 24
# Branch number: 4472
# Number of pixels in the branch: 22
# Branch number: 4473
# Number of pixels in the branch: 11
# Branch number: 4474
# Number of pixels in the branch: 4
# Branch number: 4475
# Number of pixels in the branch: 15
# Branch number: 4476
# Number of pixels in the branch: 14
# Branch number: 4477
# Number of pixels in the branch: 11
# Branch number: 4478
# Number of pixels in the branch: 3
# Branch number: 4479
# Number of pixels in the branch: 3
# Branch number: 4480
# Number of pixels in the branch: 18
# Branch number: 4481
# Number of pixels in the branch: 16
# Branch number: 4482
# Number of pixels in the branch: 10
# Branch number: 4483
# Number of pixels in the branch: 3
# Branch number: 4484
# Number of pixels in the branch: 3
# Branch number: 4485
# Number of pixels in the branch: 3
# Branch number: 4486
# Mean number of pixels in a branch: 12.342175657601427

# %%
# Iterate over the short branches and set the corresponding pixels to 0 in the binary volume
for branch in pixels_to_delete:
    if len(branch) < 10:
        for x, y, z in branch:
            sk_copy[z, y, x] = 0

print(f"Number of pixels in the volume: {np.size(sk_copy)}")
print(f"Number of pixels set to True: {np.sum(sk_copy==True)}")
print(f"Number of pixels set to False: {np.sum(sk_copy == False, dtype=np.int64)}")
# Out:
# Number of pixels in the volume: 2666222100
# Number of pixels set to True: 126702
# Number of pixels set to False: 2666095398

# %%
write_tif_volume(sk_copy, 'outputs/skeleton_cleaned.tif')

# %%
branch_data = summarize(Skeleton(sk_copy))

branch_type_0 =  branch_data[branch_data['branch-type'] == 0]
branch_type_1 =  branch_data[branch_data['branch-type'] == 1]
branch_type_2 =  branch_data[branch_data['branch-type'] == 2]
branch_type_3 =  branch_data[branch_data['branch-type'] == 3]

print(f"Number of branch type 0: {len(branch_type_0)}")
print(f"Number of branch type 1: {len(branch_type_1)}")
print(f"Number of branch type 2: {len(branch_type_2)}")
print(f"Number of branch type 3: {len(branch_type_3)}")
# Out:
# Number of branch type 0: 1236
# Number of branch type 1: 3071
# Number of branch type 2: 3223
# Number of branch type 3: 41
