# %%
import numpy as np
# import cupy as cp
# print(cp.__version__)
import tifffile as tiff
from skimage.morphology import skeletonize  # Import for skeletonization
from skan import Skeleton, summarize
from joblib import Parallel, delayed
import sys

# %%
def print_branches(skeleton_cleaned):
    skel = Skeleton(skeleton_cleaned)
    branch_data = summarize(skel)

    branch_type_0 = branch_data[branch_data['branch-type'] == 0]
    branch_type_1 = branch_data[branch_data['branch-type'] == 1]
    branch_type_2 = branch_data[branch_data['branch-type'] == 2]
    branch_type_3 = branch_data[branch_data['branch-type'] == 3]

    print(f"Number of branch type 0: {len(branch_type_0)}")
    print(f"Number of branch type 1: {len(branch_type_1)}")
    print(f"Number of branch type 2: {len(branch_type_2)}")
    print(f"Number of branch type 3: {len(branch_type_3)}")

# %%
# binary_volume = tiff.imread("/zhome/57/0/203104/specialCourse_fall24/outputs/output_volume.tif")
binary_volume = tiff.imread("C:/Users/nerea/Documents/MasterDTU/SpacialCourse_Fall24/specialCourse_fall24/outputs/skeleleton_clean_x20_th5_UNET.tif")
# Get the size of the volume
print(f'Size of the volume is: {binary_volume.shape}')
# Out:
# Size of the volume is: (200, 200, 200)

# %%
print_branches(binary_volume)
# Out:
# Number of branch type 0: 51
# Number of branch type 1: 182
# Number of branch type 2: 218
# Number of branch type 3: 2

# %%
skel = Skeleton(binary_volume)
branch_data = summarize(skel)

# %%
import cc3d
import numpy as np

labels_out = cc3d.connected_components(binary_volume)
labels_out, N = cc3d.connected_components(binary_volume, return_N=True)
print(N)
# Out:
# 79

# %%
# Initialize a dictionary to map each branch ID to its corresponding blob(s)
branch_blob_mapping = {}
pixel_blob_mapping = np.zeros_like(labels_out, dtype=int)

# Step 2: For each branch, get the coordinates and map them to the corresponding blob label(s)
for branch_id in branch_data.index:
    # Get the coordinates of the current branch in the skeleton structure
    coordinates = skel.path_coordinates(branch_id)
    
    # Fetch the labels at those coordinates from the labels_out array
    branch_labels = labels_out[coordinates[:, 0], coordinates[:, 1], coordinates[:, 2]]
    
    # Find the unique label(s) associated with this branch
    unique_blob_labels = np.unique(branch_labels)
    
    # Store the unique label(s) in the branch_blob_mapping
    if len(unique_blob_labels) > 1:
        branch_blob_mapping[branch_id] = unique_blob_labels
    else:
        branch_blob_mapping[branch_id] = unique_blob_labels[0]
    
    # Step 3: Map each pixel in this branch to its corresponding blob label(s)
    for i, coord in enumerate(coordinates):
        pixel_blob_mapping[tuple(coord)] = branch_labels[i]

# %%
def Bresenham3D(x1, y1, z1, x2, y2, z2):
    ListOfPoints = []
    ListOfPoints.append((x1, y1, z1))
    dx = abs(x2 - x1)
    dy = abs(y2 - y1)
    dz = abs(z2 - z1)
    if (x2 > x1):
        xs = 1
    else:
        xs = -1
    if (y2 > y1):
        ys = 1
    else:
        ys = -1
    if (z2 > z1):
        zs = 1
    else:
        zs = -1
 
    # Driving axis is X-axis"
    if (dx >= dy and dx >= dz):        
        p1 = 2 * dy - dx
        p2 = 2 * dz - dx
        while (x1 != x2):
            x1 += xs
            if (p1 >= 0):
                y1 += ys
                p1 -= 2 * dx
            if (p2 >= 0):
                z1 += zs
                p2 -= 2 * dx
            p1 += 2 * dy
            p2 += 2 * dz
            ListOfPoints.append((x1, y1, z1))
 
    # Driving axis is Y-axis"
    elif (dy >= dx and dy >= dz):       
        p1 = 2 * dx - dy
        p2 = 2 * dz - dy
        while (y1 != y2):
            y1 += ys
            if (p1 >= 0):
                x1 += xs
                p1 -= 2 * dy
            if (p2 >= 0):
                z1 += zs
                p2 -= 2 * dy
            p1 += 2 * dx
            p2 += 2 * dz
            ListOfPoints.append((x1, y1, z1))
 
    # Driving axis is Z-axis"
    else:        
        p1 = 2 * dy - dz
        p2 = 2 * dx - dz
        while (z1 != z2):
            z1 += zs
            if (p1 >= 0):
                y1 += ys
                p1 -= 2 * dz
            if (p2 >= 0):
                x1 += xs
                p2 -= 2 * dz
            p1 += 2 * dy
            p2 += 2 * dx
            ListOfPoints.append((x1, y1, z1))
    return ListOfPoints

# %%
import numpy as np
from scipy.spatial.distance import cdist

# Paso 1: Calcular centroides de los blobs en 3D
def calculate_centroid(blob_labels, labels_out):
    centroids = {}
    for blob in np.unique(blob_labels):
        # Encuentra las coordenadas de todos los píxeles de ese blob
        coords = np.array(np.where(labels_out == blob)).T
        # Calcula el centroide como el promedio de las coordenadas
        centroid = np.mean(coords, axis=0)
        centroids[blob] = centroid
    return centroids

# Paso 2: Encontrar los blobs más cercanos en 3D
def find_closest_blobs(centroids):
    blobs = list(centroids.keys())
    distances = cdist([centroids[blob] for blob in blobs], [centroids[blob] for blob in blobs])
    np.fill_diagonal(distances, np.inf)  # Evitar que los blobs se conecten consigo mismos
    closest_pairs = np.unravel_index(np.argmin(distances), distances.shape)
    return blobs[closest_pairs[0]], blobs[closest_pairs[1]]

# Paso 3: Conectar los blobs más cercanos con una línea recta 3D
def connect_blobs_3d(labels_out, pixel_blob_mapping, skeleton_cleaned):
    import numpy as np
    from scipy.spatial import distance

    # Copia del esqueleto para modificaciones
    skel = np.copy(skeleton_cleaned)

    # Calcular centroides de todos los blobs
    centroids = calculate_centroid(labels_out, labels_out)

    # Encontrar el par de blobs más cercanos
    blob1, blob2 = find_closest_blobs(centroids)
    print(f"Connecting blobs {blob1} and {blob2}")

    # Coordenadas de todos los puntos en cada blob
    coords_blob1 = np.array(np.where(labels_out == blob1)).T
    coords_blob2 = np.array(np.where(labels_out == blob2)).T

    # Calcular las distancias entre cada par de puntos
    distances = distance.cdist(coords_blob1, coords_blob2, 'euclidean')
    min_idx = np.unravel_index(np.argmin(distances), distances.shape)

    # Seleccionar los puntos más cercanos
    p1 = coords_blob1[min_idx[0]]
    p2 = coords_blob2[min_idx[1]]

    print(f"Closest points: {p1} in blob {blob1}, {p2} in blob {blob2}")

    # Calcular la línea de Bresenham entre los puntos (en 3D)
    line_points = Bresenham3D(p1[0], p1[1], p1[2], p2[0], p2[1], p2[2])

    # Conectar los blobs en el mapeo de píxeles
    for point in line_points:
        pixel_blob_mapping[tuple(point)] = blob1  # O usar una mezcla de ambos blobs
        skel[tuple(point)] = 1
    
    return skel

# %%
binary_volume_copy = np.copy(binary_volume)
while True:
    # Paso 4: Repetir los pasos 2 y 3 hasta que todos los blobs estén conectados
    binary_volume_copy = connect_blobs_3d(labels_out, pixel_blob_mapping, binary_volume_copy)
    
    # Free up memory by deleting unused variables
    del labels_out, pixel_blob_mapping, branch_blob_mapping
    
    labels_out, N = cc3d.connected_components(binary_volume_copy, return_N=True)
    print(f"Number of blobs: {N}")
    
    # Reinitialize pixel_blob_mapping to reduce memory usage
    # Initialize a dictionary to map each branch ID to its corresponding blob(s)
    branch_blob_mapping = {}
    pixel_blob_mapping = np.zeros_like(labels_out, dtype=int)

    skel = Skeleton(binary_volume_copy)
    branch_data = summarize(skel)

    # Step 2: For each branch, get the coordinates and map them to the corresponding blob label(s)
    for branch_id in branch_data.index:
        # Get the coordinates of the current branch in the skeleton structure
        coordinates = skel.path_coordinates(branch_id)
        
        # Fetch the labels at those coordinates from the labels_out array
        branch_labels = labels_out[coordinates[:, 0], coordinates[:, 1], coordinates[:, 2]]
        
        # Find the unique label(s) associated with this branch
        unique_blob_labels = np.unique(branch_labels)
        
        # Store the unique label(s) in the branch_blob_mapping
        if len(unique_blob_labels) > 1:
            branch_blob_mapping[branch_id] = unique_blob_labels
        else:
            branch_blob_mapping[branch_id] = unique_blob_labels[0]
        
        # Step 3: Map each pixel in this branch to its corresponding blob label(s)
        for i, coord in enumerate(coordinates):
            pixel_blob_mapping[tuple(coord)] = branch_labels[i]
    
    if N == 2:
        print("All blobs are connected!")
        break
# Out:
# Connecting blobs 71 and 72
# Closest points: [134  68 141] in blob 71, [134  70 141] in blob 72
# Number of blobs: 78
# Connecting blobs 39 and 40
# Closest points: [ 85 132 117] in blob 39, [ 85 134 116] in blob 40
# Number of blobs: 77
# Connecting blobs 76 and 77
# Closest points: [157   1 195] in blob 76, [160   1 195] in blob 77
# Number of blobs: 76
# Connecting blobs 34 and 39
# Closest points: [ 82 132 118] in blob 34, [ 85 132 117] in blob 39
# Number of blobs: 75
# Connecting blobs 69 and 70
# Closest points: [134  70 141] in blob 69, [136  71 141] in blob 70
# Number of blobs: 74
# Connecting blobs 33 and 36
# Closest points: [ 82 100  85] in blob 33, [ 84 100  82] in blob 36
# Number of blobs: 73
# Connecting blobs 54 and 56
# Closest points: [106  18  80] in blob 54, [108  20  78] in blob 56
# Number of blobs: 72
# Connecting blobs 5 and 6
# Closest points: [ 26 132  15] in blob 5, [ 28 131  15] in blob 6
# Number of blobs: 71
# Connecting blobs 3 and 4
# Closest points: [ 17 140  12] in blob 3, [ 19 139  12] in blob 4
# Number of blobs: 70
# Connecting blobs 7 and 8
# Closest points: [ 37 196   3] in blob 7, [ 39 194   5] in blob 8
# Number of blobs: 69
# Connecting blobs 60 and 62
# Closest points: [121  37 119] in blob 60, [123  37 121] in blob 62
# Number of blobs: 68
# Connecting blobs 66 and 67
# Closest points: [148  38 151] in blob 66, [149  35 151] in blob 67
# Number of blobs: 67
# Connecting blobs 59 and 60
# Closest points: [119  32 120] in blob 59, [120  34 119] in blob 60
# Number of blobs: 66
# Connecting blobs 46 and 52
# Closest points: [106   8  89] in blob 46, [108   7  90] in blob 52
# Number of blobs: 65
# Connecting blobs 48 and 50
# Closest points: [103  87 107] in blob 48, [105  86 109] in blob 50
# Number of blobs: 64
# Connecting blobs 32 and 35
# Closest points: [ 82 148 110] in blob 32, [ 85 143 112] in blob 35
# Number of blobs: 63
# Connecting blobs 60 and 61
# Closest points: [140  41 140] in blob 60, [143  39 143] in blob 61
# Number of blobs: 62
# Connecting blobs 34 and 37
# Closest points: [87 23 86] in blob 34, [88 21 87] in blob 37
# Number of blobs: 61
# Connecting blobs 0 and 43
# Closest points: [ 97  95 105] in blob 0, [ 98  95 105] in blob 43
# Number of blobs: 61
# Connecting blobs 0 and 43
# Closest points: [ 96  95 105] in blob 0, [ 97  95 105] in blob 43
# Number of blobs: 61
# Connecting blobs 0 and 43
# Closest points: [ 95  95 105] in blob 0, [ 96  95 105] in blob 43
# Number of blobs: 61
# Connecting blobs 45 and 48
# Closest points: [105  17  82] in blob 45, [106  18  80] in blob 48
# Number of blobs: 60
# Connecting blobs 0 and 42
# Closest points: [ 94  95 105] in blob 0, [ 95  95 105] in blob 42
# Number of blobs: 60
# Connecting blobs 0 and 42
# Closest points: [ 93  95 105] in blob 0, [ 94  95 105] in blob 42
# Number of blobs: 60
# Connecting blobs 33 and 37
# Closest points: [ 84 117  88] in blob 33, [ 88 112  92] in blob 37
# Number of blobs: 59
# Connecting blobs 52 and 54
# Closest points: [117  72 121] in blob 52, [121  69 125] in blob 54
# Number of blobs: 58
# Connecting blobs 0 and 41
# Closest points: [ 92  95 105] in blob 0, [ 93  95 105] in blob 41
# Number of blobs: 58
# Connecting blobs 38 and 40
# Closest points: [ 91  97 105] in blob 38, [ 92  95 105] in blob 40
# Number of blobs: 57
# Connecting blobs 11 and 13
# Closest points: [58 77 41] in blob 11, [56 77 42] in blob 13
# Number of blobs: 56
# Connecting blobs 0 and 37
# Closest points: [ 88  98 110] in blob 0, [ 89  98 110] in blob 37
# Number of blobs: 56
# Connecting blobs 0 and 36
# Closest points: [ 87  98 110] in blob 0, [ 88  98 110] in blob 36
# Number of blobs: 56
# Connecting blobs 0 and 35
# Closest points: [ 86  98 110] in blob 0, [ 87  98 110] in blob 35
# Number of blobs: 56
# Connecting blobs 0 and 35
# Closest points: [ 85  98 110] in blob 0, [ 86  98 110] in blob 35
# Number of blobs: 56
# Connecting blobs 0 and 34
# Closest points: [ 84  98 110] in blob 0, [ 85  98 110] in blob 34
# Number of blobs: 56
# Connecting blobs 0 and 32
# Closest points: [ 83  98 110] in blob 0, [ 84  98 110] in blob 32
# Number of blobs: 56
# Connecting blobs 30 and 36
# Closest points: [ 85 133 118] in blob 30, [ 88 133 119] in blob 36
# Number of blobs: 55
# Connecting blobs 0 and 32
# Closest points: [ 82  98 110] in blob 0, [ 83  98 110] in blob 32
# Number of blobs: 55
# Connecting blobs 19 and 23
# Closest points: [71 97 25] in blob 19, [76 90 29] in blob 23
# Number of blobs: 54
# Connecting blobs 0 and 28
# Closest points: [ 81  98 110] in blob 0, [ 82  98 110] in blob 28
# Number of blobs: 54
# Connecting blobs 13 and 15
# Closest points: [ 58  45 131] in blob 13, [ 64  51 131] in blob 15
# Number of blobs: 53
# Connecting blobs 3 and 4
# Closest points: [ 22 136  14] in blob 3, [ 24 134  15] in blob 4
# Number of blobs: 52
# Connecting blobs 0 and 25
# Closest points: [ 80  98 110] in blob 0, [ 81  98 110] in blob 25
# Number of blobs: 52
# Connecting blobs 0 and 24
# Closest points: [ 79  98 110] in blob 0, [ 80  98 110] in blob 24
# Number of blobs: 52
# Connecting blobs 0 and 24
# Closest points: [ 78  98 110] in blob 0, [ 79  98 110] in blob 24
# Number of blobs: 52
# Connecting blobs 0 and 24
# Closest points: [ 77  98 110] in blob 0, [ 78  98 110] in blob 24
# Number of blobs: 52
# Connecting blobs 0 and 24
# Closest points: [ 76  98 110] in blob 0, [ 77  98 110] in blob 24
# Number of blobs: 52
# Connecting blobs 31 and 34
# Closest points: [90 18 90] in blob 31, [91 16 91] in blob 34
# Number of blobs: 51
# Connecting blobs 0 and 22
# Closest points: [ 75  98 110] in blob 0, [ 76  98 110] in blob 22
# Number of blobs: 51
# Connecting blobs 40 and 46
# Closest points: [115  36 113] in blob 40, [117  36 115] in blob 46
# Number of blobs: 50
# Connecting blobs 0 and 20
# Closest points: [ 74  98 110] in blob 0, [ 75  98 110] in blob 20
# Number of blobs: 50
# Connecting blobs 48 and 49
# Closest points: [143  40 144] in blob 48, [148  38 150] in blob 49
# Number of blobs: 49
# Connecting blobs 0 and 20
# Closest points: [ 73  98 110] in blob 0, [ 74  98 110] in blob 20
# Number of blobs: 49
# Connecting blobs 0 and 20
# Closest points: [ 72  98 110] in blob 0, [ 73  98 110] in blob 20
# Number of blobs: 49
# Connecting blobs 0 and 19
# Closest points: [ 71  98 110] in blob 0, [ 72  98 110] in blob 19
# Number of blobs: 49
# Connecting blobs 0 and 18
# Closest points: [ 70  98 110] in blob 0, [ 71  98 110] in blob 18
# Number of blobs: 49
# Connecting blobs 36 and 37
# Closest points: [100  10  91] in blob 36, [100  16  85] in blob 37
# Number of blobs: 48
# Connecting blobs 5 and 7
# Closest points: [ 38 115  32] in blob 5, [ 42 111  23] in blob 7
# Number of blobs: 47
# Connecting blobs 0 and 16
# Closest points: [ 69  98 110] in blob 0, [ 70  98 110] in blob 16
# Number of blobs: 47
# Connecting blobs 0 and 36
# Closest points: [ 99  92 105] in blob 0, [100  92 105] in blob 36
# Number of blobs: 47
# Connecting blobs 0 and 35
# Closest points: [ 98  92 105] in blob 0, [ 99  92 105] in blob 35
# Number of blobs: 47
# Connecting blobs 0 and 35
# Closest points: [ 97  92 105] in blob 0, [ 98  92 105] in blob 35
# Number of blobs: 47
# Connecting blobs 0 and 35
# Closest points: [ 96  92 105] in blob 0, [ 97  92 105] in blob 35
# Number of blobs: 47
# Connecting blobs 0 and 35
# Closest points: [ 95  92 105] in blob 0, [ 96  92 105] in blob 35
# Number of blobs: 47
# Connecting blobs 0 and 34
# Closest points: [ 94  92 105] in blob 0, [ 95  92 105] in blob 34
# Number of blobs: 47
# Connecting blobs 0 and 34
# Closest points: [ 93  92 105] in blob 0, [ 94  92 105] in blob 34
# Number of blobs: 47
# Connecting blobs 0 and 34
# Closest points: [ 92  92 105] in blob 0, [ 93  92 105] in blob 34
# Number of blobs: 47
# Connecting blobs 0 and 33
# Closest points: [ 91  92 105] in blob 0, [ 92  92 105] in blob 33
# Number of blobs: 47
# Connecting blobs 0 and 33
# Closest points: [ 90  92 105] in blob 0, [ 91  92 105] in blob 33
# Number of blobs: 47
# Connecting blobs 0 and 33
# Closest points: [ 89  92 105] in blob 0, [ 90  92 105] in blob 33
# Number of blobs: 47
# Connecting blobs 0 and 33
# Closest points: [ 88  92 105] in blob 0, [ 89  92 105] in blob 33
# Number of blobs: 47
# Connecting blobs 16 and 32
# Closest points: [ 92  95 105] in blob 16, [ 92  92 105] in blob 32
# Number of blobs: 46
# Connecting blobs 0 and 16
# Closest points: [ 68  98 110] in blob 0, [ 69  98 110] in blob 16
# Number of blobs: 46
# Connecting blobs 0 and 15
# Closest points: [ 67  98 110] in blob 0, [ 68  98 110] in blob 15
# Number of blobs: 46
# Connecting blobs 0 and 14
# Closest points: [ 66  98 110] in blob 0, [ 67  98 110] in blob 14
# Number of blobs: 46
# Connecting blobs 0 and 13
# Closest points: [ 65  98 110] in blob 0, [ 66  98 110] in blob 13
# Number of blobs: 46
# Connecting blobs 0 and 13
# Closest points: [ 64  98 110] in blob 0, [ 65  98 110] in blob 13
# Number of blobs: 46
# Connecting blobs 0 and 13
# Closest points: [ 63  98 110] in blob 0, [ 64  98 110] in blob 13
# Number of blobs: 46
# Connecting blobs 30 and 35
# Closest points: [98 11 91] in blob 30, [100  10  91] in blob 35
# Number of blobs: 45
# Connecting blobs 22 and 28
# Closest points: [ 76 155 111] in blob 22, [ 82 148 110] in blob 28
# Number of blobs: 44
# Connecting blobs 0 and 13
# Closest points: [ 62  98 110] in blob 0, [ 63  98 110] in blob 13
# Number of blobs: 44
# Connecting blobs 0 and 13
# Closest points: [ 61  98 110] in blob 0, [ 62  98 110] in blob 13
# Number of blobs: 44
# Connecting blobs 35 and 38
# Closest points: [117  30 120] in blob 35, [117  28 121] in blob 38
# Number of blobs: 43
# Connecting blobs 15 and 18
# Closest points: [70 57 58] in blob 15, [72 56 57] in blob 18
# Number of blobs: 42
# Connecting blobs 0 and 13
# Closest points: [ 60  98 110] in blob 0, [ 61  98 110] in blob 13
# Number of blobs: 42
# Connecting blobs 1 and 2
# Closest points: [ 10 154   7] in blob 1, [ 11 152   8] in blob 2
# Number of blobs: 41
# Connecting blobs 30 and 31
# Closest points: [93 83 72] in blob 30, [96 72 79] in blob 31
# Number of blobs: 40
# Connecting blobs 0 and 12
# Closest points: [ 59  98 110] in blob 0, [ 60  98 110] in blob 12
# Number of blobs: 40
# Connecting blobs 35 and 36
# Closest points: [115  63 113] in blob 35, [117  72 121] in blob 36
# Number of blobs: 39
# Connecting blobs 0 and 12
# Closest points: [ 58  98 110] in blob 0, [ 59  98 110] in blob 12
# Number of blobs: 39
# Connecting blobs 0 and 12
# Closest points: [ 57  98 110] in blob 0, [ 58  98 110] in blob 12
# Number of blobs: 39
# Connecting blobs 3 and 4
# Closest points: [ 40 113  22] in blob 3, [ 42 111  23] in blob 4
# Number of blobs: 38
# Connecting blobs 0 and 9
# Closest points: [ 56  98 110] in blob 0, [ 57  98 110] in blob 9
# Number of blobs: 38
# Connecting blobs 0 and 9
# Closest points: [ 55  98 110] in blob 0, [ 56  98 110] in blob 9
# Number of blobs: 38
# Connecting blobs 0 and 9
# Closest points: [ 54  98 110] in blob 0, [ 55  98 110] in blob 9
# Number of blobs: 38
# Connecting blobs 10 and 11
# Closest points: [ 64  53 129] in blob 10, [ 58  59 122] in blob 11
# Number of blobs: 37
# Connecting blobs 0 and 9
# Closest points: [ 53  98 110] in blob 0, [ 54  98 110] in blob 9
# Number of blobs: 37
# Connecting blobs 22 and 24
# Closest points: [ 82 100  85] in blob 22, [ 88 111  92] in blob 24
# Number of blobs: 36
# Connecting blobs 0 and 9
# Closest points: [ 52  98 110] in blob 0, [ 53  98 110] in blob 9
# Number of blobs: 36
# Connecting blobs 24 and 25
# Closest points: [91 16 91] in blob 24, [91 15 93] in blob 25
# Number of blobs: 35
# Connecting blobs 0 and 9
# Closest points: [ 51  98 110] in blob 0, [ 52  98 110] in blob 9
# Number of blobs: 35
# Connecting blobs 0 and 9
# Closest points: [ 50  98 110] in blob 0, [ 51  98 110] in blob 9
# Number of blobs: 35
# Connecting blobs 32 and 34
# Closest points: [136  40 135] in blob 32, [140  40 139] in blob 34
# Number of blobs: 34
# Connecting blobs 0 and 9
# Closest points: [ 49  98 110] in blob 0, [ 50  98 110] in blob 9
# Number of blobs: 34
# Connecting blobs 0 and 9
# Closest points: [ 48  98 110] in blob 0, [ 49  98 110] in blob 9
# Number of blobs: 34
# Connecting blobs 29 and 33
# Closest points: [124  68 141] in blob 29, [134  68 141] in blob 33
# Number of blobs: 33
# Connecting blobs 0 and 7
# Closest points: [ 47  98 110] in blob 0, [ 48  98 110] in blob 7
# Number of blobs: 33
# Connecting blobs 0 and 7
# Closest points: [ 46  98 110] in blob 0, [ 47  98 110] in blob 7
# Number of blobs: 33
# Connecting blobs 0 and 7
# Closest points: [ 45  98 110] in blob 0, [ 46  98 110] in blob 7
# Number of blobs: 33
# Connecting blobs 0 and 5
# Closest points: [ 44  98 110] in blob 0, [ 45  98 110] in blob 5
# Number of blobs: 33
# Connecting blobs 23 and 25
# Closest points: [ 87 118 127] in blob 23, [ 88 112 130] in blob 25
# Number of blobs: 32
# Connecting blobs 0 and 5
# Closest points: [ 43  98 110] in blob 0, [ 44  98 110] in blob 5
# Number of blobs: 32
# Connecting blobs 15 and 16
# Closest points: [ 72 120  49] in blob 15, [ 75 128  51] in blob 16
# Number of blobs: 31
# Connecting blobs 0 and 5
# Closest points: [ 42  98 110] in blob 0, [ 43  98 110] in blob 5
# Number of blobs: 31
# Connecting blobs 0 and 5
# Closest points: [ 41  98 110] in blob 0, [ 42  98 110] in blob 5
# Number of blobs: 31
# Connecting blobs 16 and 25
# Closest points: [102  42 101] in blob 16, [104  43 101] in blob 25
# Number of blobs: 30
# Connecting blobs 26 and 28
# Closest points: [124  66 131] in blob 26, [121  68 125] in blob 28
# Number of blobs: 29
# Connecting blobs 0 and 21
# Closest points: [ 81 100  85] in blob 0, [ 82 100  85] in blob 21
# Number of blobs: 29
# Connecting blobs 0 and 5
# Closest points: [ 40  98 110] in blob 0, [ 41  98 110] in blob 5
# Number of blobs: 29
# Connecting blobs 0 and 20
# Closest points: [ 80 100  85] in blob 0, [ 81 100  85] in blob 20
# Number of blobs: 29
# Connecting blobs 0 and 19
# Closest points: [ 79 100  85] in blob 0, [ 80 100  85] in blob 19
# Number of blobs: 29
# Connecting blobs 6 and 7
# Closest points: [ 46  83 107] in blob 6, [ 46  89 106] in blob 7
# Number of blobs: 28
# Connecting blobs 0 and 18
# Closest points: [ 78 100  85] in blob 0, [ 79 100  85] in blob 18
# Number of blobs: 28
# Connecting blobs 0 and 5
# Closest points: [ 39  98 110] in blob 0, [ 40  98 110] in blob 5
# Number of blobs: 28
# Connecting blobs 0 and 18
# Closest points: [ 77 100  85] in blob 0, [ 78 100  85] in blob 18
# Number of blobs: 28
# Connecting blobs 0 and 18
# Closest points: [ 76 100  85] in blob 0, [ 77 100  85] in blob 18
# Number of blobs: 28
# Connecting blobs 0 and 5
# Closest points: [ 38  98 110] in blob 0, [ 39  98 110] in blob 5
# Number of blobs: 28
# Connecting blobs 0 and 16
# Closest points: [ 75 100  85] in blob 0, [ 76 100  85] in blob 16
# Number of blobs: 28
# Connecting blobs 10 and 15
# Closest points: [ 66 101  76] in blob 10, [ 75 100  85] in blob 15
# Number of blobs: 27
# Connecting blobs 0 and 5
# Closest points: [ 37  98 110] in blob 0, [ 38  98 110] in blob 5
# Number of blobs: 27
# Connecting blobs 0 and 4
# Closest points: [ 36  98 110] in blob 0, [ 37  98 110] in blob 4
# Number of blobs: 27
# Connecting blobs 0 and 4
# Closest points: [ 35  98 110] in blob 0, [ 36  98 110] in blob 4
# Number of blobs: 27
# Connecting blobs 0 and 4
# Closest points: [ 34  98 110] in blob 0, [ 35  98 110] in blob 4
# Number of blobs: 27
# Connecting blobs 1 and 2
# Closest points: [ 16 142  12] in blob 1, [ 17 140  12] in blob 2
# Number of blobs: 26
# Connecting blobs 3 and 9
# Closest points: [92 93 94] in blob 3, [ 83 101  86] in blob 9
# Number of blobs: 25
# Connecting blobs 0 and 3
# Closest points: [ 33  98 110] in blob 0, [ 34  98 110] in blob 3
# Number of blobs: 25
# Connecting blobs 0 and 3
# Closest points: [ 32  98 110] in blob 0, [ 33  98 110] in blob 3
# Number of blobs: 25
# Connecting blobs 0 and 3
# Closest points: [ 31  98 110] in blob 0, [ 32  98 110] in blob 3
# Number of blobs: 25
# Connecting blobs 0 and 3
# Closest points: [ 30  98 110] in blob 0, [ 31  98 110] in blob 3
# Number of blobs: 25
# Connecting blobs 0 and 2
# Closest points: [ 29  98 110] in blob 0, [ 30  98 110] in blob 2
# Number of blobs: 25
# Connecting blobs 0 and 2
# Closest points: [ 28  98 110] in blob 0, [ 29  98 110] in blob 2
# Number of blobs: 25
# Connecting blobs 0 and 2
# Closest points: [ 27  98 110] in blob 0, [ 28  98 110] in blob 2
# Number of blobs: 25
# Connecting blobs 0 and 2
# Closest points: [ 26  98 110] in blob 0, [ 27  98 110] in blob 2
# Number of blobs: 25
# Connecting blobs 9 and 16
# Closest points: [81 39 73] in blob 9, [82 37 74] in blob 16
# Number of blobs: 24
# Connecting blobs 0 and 2
# Closest points: [ 25  98 110] in blob 0, [ 26  98 110] in blob 2
# Number of blobs: 24
# Connecting blobs 6 and 16
# Closest points: [80 63 41] in blob 6, [82 65 34] in blob 16
# Number of blobs: 23
# Connecting blobs 0 and 2
# Closest points: [ 24  98 110] in blob 0, [ 25  98 110] in blob 2
# Number of blobs: 23
# Connecting blobs 0 and 2
# Closest points: [ 23  98 110] in blob 0, [ 24  98 110] in blob 2
# Number of blobs: 23
# Connecting blobs 0 and 2
# Closest points: [ 22  98 110] in blob 0, [ 23  98 110] in blob 2
# Number of blobs: 23
# Connecting blobs 20 and 21
# Closest points: [116  86 139] in blob 20, [114  87 140] in blob 21
# Number of blobs: 22
# Connecting blobs 0 and 2
# Closest points: [ 21  98 110] in blob 0, [ 22  98 110] in blob 2
# Number of blobs: 22
# Connecting blobs 6 and 11
# Closest points: [63 88 25] in blob 6, [72 95 26] in blob 11
# Number of blobs: 21
# Connecting blobs 6 and 7
# Closest points: [52 94 29] in blob 6, [49 95 42] in blob 7
# Number of blobs: 20
# Connecting blobs 0 and 2
# Closest points: [ 20  98 110] in blob 0, [ 21  98 110] in blob 2
# Number of blobs: 20
# Connecting blobs 0 and 2
# Closest points: [ 19  98 110] in blob 0, [ 20  98 110] in blob 2
# Number of blobs: 20
# Connecting blobs 0 and 2
# Closest points: [ 18  98 110] in blob 0, [ 19  98 110] in blob 2
# Number of blobs: 20
# Connecting blobs 0 and 2
# Closest points: [ 17  98 110] in blob 0, [ 18  98 110] in blob 2
# Number of blobs: 20
# Connecting blobs 0 and 2
# Closest points: [ 16  98 110] in blob 0, [ 17  98 110] in blob 2
# Number of blobs: 20
# Connecting blobs 0 and 2
# Closest points: [ 15  98 110] in blob 0, [ 16  98 110] in blob 2
# Number of blobs: 20
# Connecting blobs 0 and 2
# Closest points: [ 14  98 110] in blob 0, [ 15  98 110] in blob 2
# Number of blobs: 20
# Connecting blobs 0 and 2
# Closest points: [ 13  98 110] in blob 0, [ 14  98 110] in blob 2
# Number of blobs: 20
# Connecting blobs 0 and 2
# Closest points: [ 12  98 110] in blob 0, [ 13  98 110] in blob 2
# Number of blobs: 20
# Connecting blobs 2 and 5
# Closest points: [ 46  98 110] in blob 2, [ 46  96 102] in blob 5
# Number of blobs: 19
# Connecting blobs 10 and 15
# Closest points: [93 76 77] in blob 10, [95 75 77] in blob 15
# Number of blobs: 18
# Connecting blobs 11 and 13
# Closest points: [ 85 143 112] in blob 11, [ 88 138 117] in blob 13
# Number of blobs: 17
# Connecting blobs 14 and 16
# Closest points: [123  37 121] in blob 14, [128  38 126] in blob 16
# Number of blobs: 15
# Connecting blobs 0 and 2
# Closest points: [ 11  98 110] in blob 0, [ 12  98 110] in blob 2
# Number of blobs: 15
# Connecting blobs 0 and 2
# Closest points: [ 10  98 110] in blob 0, [ 11  98 110] in blob 2
# Number of blobs: 15
# Connecting blobs 0 and 2
# Closest points: [  9  98 110] in blob 0, [ 10  98 110] in blob 2
# Number of blobs: 15
# Connecting blobs 0 and 2
# Closest points: [  8  98 110] in blob 0, [  9  98 110] in blob 2
# Number of blobs: 15
# Connecting blobs 0 and 2
# Closest points: [  7  98 110] in blob 0, [  8  98 110] in blob 2
# Number of blobs: 15
# Connecting blobs 0 and 2
# Closest points: [  6  98 110] in blob 0, [  7  98 110] in blob 2
# Number of blobs: 15
# Connecting blobs 0 and 2
# Closest points: [  5  98 110] in blob 0, [  6  98 110] in blob 2
# Number of blobs: 15
# Connecting blobs 0 and 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 binary_volume_copy = np.copy(binary_volume)
#       2 while True:
#       3     # Paso 4: Repetir los pasos 2 y 3 hasta que todos los blobs estén conectados
# ----> 4     binary_volume_copy = connect_blobs_3d(labels_out, pixel_blob_mapping, binary_volume_copy)
#       6     # Free up memory by deleting unused variables
#       7     del labels_out, pixel_blob_mapping, branch_blob_mapping
#
# Cell In[9], line 44, in connect_blobs_3d(labels_out, pixel_blob_mapping, skeleton_cleaned)
#      42 # Calcular las distancias entre cada par de puntos
#      43 distances = distance.cdist(coords_blob1, coords_blob2, 'euclidean')
# ---> 44 min_idx = np.unravel_index(np.argmin(distances), distances.shape)
#      46 # Seleccionar los puntos más cercanos
#      47 p1 = coords_blob1[min_idx[0]]
#
# File <__array_function__ internals>:200, in argmin(*args, **kwargs)
#
# File c:\Users\nerea\anaconda3\envs\SCenv\Lib\site-packages\numpy\core\fromnumeric.py:1338, in argmin(a, axis, out, keepdims)
#    1251 """
#    1252 Returns the indices of the minimum values along an axis.
#    1253
#    (...)
#    1335 (2, 1, 4)
#    1336 """
#    1337 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1338 return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#
# File c:\Users\nerea\anaconda3\envs\SCenv\Lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
# blob_mapping_connected = connect_blobs_3d(labels_out, pixel_blob_mapping, binary_volume)
tiff.imwrite('binary_volume_copy_UNET.tif', binary_volume_copy)
